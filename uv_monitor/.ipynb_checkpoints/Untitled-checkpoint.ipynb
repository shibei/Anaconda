# %%
from raw_data import RawData
from pre_process import DataClean as dc
from pre_process import DateData as dd
from data_analysis import Analysis
from data_merge import Merge
from storage import Storage
from report import Report
import numpy as np
from email_data import Mail

# %%
day1 = 1
cycle = 1
day2 = day1 + cycle*7

# %%
a= RawData(day1=day1,day2=day2)
uvData = a.getUvData()
apData = a.getApData()
data400 = a.get400Data()
devInfo = a.getDevInfo()
hosInfo = a.getHosInfo()

# %%
aa = dc(uvData,apData)
uvDataGood ,apDataGood = aa.uvDataClean(),aa.apDataClean()
aaa = dd(uvDataGood,apDataGood,day1=day1,day2=day2)
uvDay1,uvDay2 = aaa.uvDay1Lite,aaa.uvDay2Lite

# %%
aaaa = Analysis(uvDay1,uvDay2)
trouble,rate = aaaa.comparison()

# %%
aaaaa = Merge(troubleHos=trouble,uvDay1=uvDay1,uvDay2=uvDay2,rate=rate,data400=data400,devInfo=devInfo,hosInfo=hosInfo)
dataDict = aaaaa.allData()

# %%
save = Storage(data=dataDict,day=day1,cycle=cycle)

# %%
excelPath = save.toExcel()

# %%
save.toMySql()

# %%
r = Report(data=dataDict,day=day1,cycle=cycle)

# %%
reportPath = r.makeReport()
# Out:
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count       dhcp      portal   prelogin     login webforward  \
# title
# troubleUvDay1        9        417         316        150       111         94
# troubleUvDay2       10        445         319        158       124        108
# troubleRate       -0.1 -0.0629213 -0.00940439 -0.0506329 -0.104839   -0.12963
#
#               hardforward forward_rate
# title
# troubleUvDay1          89     0.213429
# troubleUvDay2         109     0.244944
# troubleRate     -0.183486     -0.12866
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count       dhcp portal prelogin login webforward  \
# title
# troubleUvDay1         6        432    384       99    95         67
# troubleUvDay2         7        409      0        0     0          0
# troubleRate   -0.142857  0.0562347    NaN      NaN   NaN        NaN
#
#               hardforward forward_rate
# title
# troubleUvDay1          71     0.164352
# troubleUvDay2           0            0
# troubleRate           NaN          NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                 ap_count      dhcp portal   prelogin      login webforward  \
# title
# troubleUvDay1         13       213    208         74         67          3
# troubleUvDay2         14       241    208         68         63         58
# troubleRate   -0.0714286 -0.116183      0  0.0882353  0.0634921  -0.948276
#
#               hardforward forward_rate
# title
# troubleUvDay1          54     0.253521
# troubleUvDay2           0            0
# troubleRate           NaN          NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count      dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1       27       627    582      349   341        310         312
# troubleUvDay2       32       715      0        0     0          0           0
# troubleRate   -0.15625 -0.123077    NaN      NaN   NaN        NaN         NaN
#
#               forward_rate
# title
# troubleUvDay1     0.497608
# troubleUvDay2            0
# troubleRate            NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count       dhcp portal prelogin login webforward  \
# title
# troubleUvDay1        46       2072   1211      697   668         49
# troubleUvDay2        61       2256      0        0     0          0
# troubleRate   -0.245902 -0.0815603    NaN      NaN   NaN        NaN
#
#               hardforward forward_rate
# title
# troubleUvDay1         569     0.274614
# troubleUvDay2           0            0
# troubleRate           NaN          NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count      dhcp    portal   prelogin     login webforward  \
# title
# troubleUvDay1        52      2389      1904       1226       941        800
# troubleUvDay2        70      2736      2172       1344      1027        869
# troubleRate   -0.257143 -0.126827 -0.123389 -0.0877976 -0.083739 -0.0794016
#
#               hardforward forward_rate
# title
# troubleUvDay1         783     0.327752
# troubleUvDay2         904     0.330409
# troubleRate      -0.13385  -0.00804202
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count  dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        0     0      0        0     0          0           0
# troubleUvDay2       32  1173      0        0     0          0           0
# troubleRate         -1    -1    NaN      NaN   NaN        NaN         NaN
#
#               forward_rate
# title
# troubleUvDay1            0
# troubleUvDay2            0
# troubleRate            NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        0    0      0        0     0          0           0
# troubleUvDay2       62  886    728      476   456        413         407
# troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#               forward_rate
# title
# troubleUvDay1            0
# troubleUvDay2     0.459368
# troubleRate             -1
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count      dhcp    portal  prelogin     login webforward  \
# title
# troubleUvDay1        22       919       582       396       356        293
# troubleUvDay2        36      1033       683       493       449        363
# troubleRate   -0.388889 -0.110358 -0.147877 -0.196755 -0.207127  -0.192837
#
#               hardforward forward_rate
# title
# troubleUvDay1         313     0.340588
# troubleUvDay2         384     0.371733
# troubleRate     -0.184896   -0.0837839
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count      dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        9       368    348      194   188         32         145
# troubleUvDay2       10       331      0        0     0          0           0
# troubleRate       -0.1  0.111782    NaN      NaN   NaN        NaN         NaN
#
#               forward_rate
# title
# troubleUvDay1     0.394022
# troubleUvDay2            0
# troubleRate            NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count        dhcp portal prelogin login webforward  \
# title
# troubleUvDay1         8         752    694      402   387        226
# troubleUvDay2         9         748      0        0     0          0
# troubleRate   -0.111111  0.00534759    NaN      NaN   NaN        NaN
#
#               hardforward forward_rate
# title
# troubleUvDay1         278     0.369681
# troubleUvDay2           0            0
# troubleRate           NaN          NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count       dhcp portal prelogin login webforward  \
# title
# troubleUvDay1        7        584    489      127   125         19
# troubleUvDay2        8        578      0        0     0          0
# troubleRate     -0.125  0.0103806    NaN      NaN   NaN        NaN
#
#               hardforward forward_rate
# title
# troubleUvDay1         109     0.186644
# troubleUvDay2           0            0
# troubleRate           NaN          NaN
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        0    0      0        0     0          0           0
# troubleUvDay2        6  554    405      244   212        180         172
# troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#               forward_rate
# title
# troubleUvDay1            0
# troubleUvDay2     0.310469
# troubleRate             -1
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        0    0      0        0     0          0           0
# troubleUvDay2       17  568    347      139    99         80          76
# troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#               forward_rate
# title
# troubleUvDay1            0
# troubleUvDay2     0.133803
# troubleRate             -1
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count      dhcp    portal  prelogin     login webforward  \
# title
# troubleUvDay1       15       302       173       104        80         70
# troubleUvDay2       15       442       272       147       126        104
# troubleRate          0 -0.316742 -0.363971 -0.292517 -0.365079  -0.326923
#
#               hardforward forward_rate
# title
# troubleUvDay1          62     0.205298
# troubleUvDay2         109     0.246606
# troubleRate     -0.431193    -0.167507
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count dhcp portal prelogin login webforward hardforward  \
# title
# troubleUvDay1        0    0      0        0     0          0           0
# troubleUvDay2        2  330    277      201   167        146         135
# troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#               forward_rate
# title
# troubleUvDay1            0
# troubleUvDay2     0.409091
# troubleRate             -1
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk               ap_count      dhcp    portal  prelogin     login webforward  \
# title
# troubleUvDay1       15       219       156       100        89         74
# troubleUvDay2       15       443       319       208       192        160
# troubleRate          0 -0.505643 -0.510972 -0.519231 -0.536458    -0.5375
#
#               hardforward forward_rate
# title
# troubleUvDay1          78     0.356164
# troubleUvDay2         176     0.397291
# troubleRate     -0.556818    -0.103518
# hosDatakkkkkkkkkkkkkkkkkkkkkkkkkkk                ap_count      dhcp portal prelogin login webforward  \
# title
# troubleUvDay1        14       742    631      294   283        262
# troubleUvDay2        33      1420      0        0     0          0
# troubleRate   -0.575758 -0.477465    NaN      NaN   NaN        NaN
#
#               hardforward forward_rate
# title
# troubleUvDay1         263     0.354447
# troubleUvDay2           0            0
# troubleRate           NaN          NaN

# %%
pathList = [excelPath,reportPath]

# %%
pathList
# Out:
# ['/root/ipython/UV分析结果/三周对比/三周对比_2017-12-10.xlsx',
#  '/root/ipython/UV分析结果/Report/三周对比/三周对比分析——20171210.docx']

# %%
m = Mail(pathList=pathList,day=day1,cycle=cycle)

# %%
m.sendEmail()

# %%
dataDict['troubleRate']
# Out:
#                   故障类型  ap_count      dhcp    portal  prelogin     login  \
# hos_id
# 123               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 134               AP离线 -0.100000 -0.062921 -0.009404 -0.050633 -0.104839
# 188               AP离线 -0.142857  0.056235       NaN       NaN       NaN
# 195     webforward打点故障 -0.071429 -0.116183  0.000000  0.088235  0.063492
# 201               AP离线 -0.156250 -0.123077       NaN       NaN       NaN
# 274               AP离线 -0.245902 -0.081560       NaN       NaN       NaN
# 317               AP离线 -0.257143 -0.126827 -0.123389 -0.087798 -0.083739
# 321               网关离线 -1.000000 -1.000000       NaN       NaN       NaN
# 451               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 608               AP离线 -0.388889 -0.110358 -0.147877 -0.196755 -0.207127
# 609               AP离线 -0.100000  0.111782       NaN       NaN       NaN
# 634               AP离线 -0.111111  0.005348       NaN       NaN       NaN
# 720               AP离线 -0.125000  0.010381       NaN       NaN       NaN
# 748               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 804               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 873             硬件放行故障  0.000000 -0.316742 -0.363971 -0.292517 -0.365079
# 915               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 924      未知  dhcp<-0.4  0.000000 -0.505643 -0.510972 -0.519231 -0.536458
# 1147              AP离线 -0.575758 -0.477465       NaN       NaN       NaN
#
#         webforward  hardforward  forward_rate
# hos_id
# 123      -1.000000    -1.000000     -1.000000
# 134      -0.129630    -0.183486     -0.128660
# 188            NaN          NaN           NaN
# 195      -0.948276          NaN           NaN
# 201            NaN          NaN           NaN
# 274            NaN          NaN           NaN
# 317      -0.079402    -0.133850     -0.008042
# 321            NaN          NaN           NaN
# 451      -1.000000    -1.000000     -1.000000
# 608      -0.192837    -0.184896     -0.083784
# 609            NaN          NaN           NaN
# 634            NaN          NaN           NaN
# 720            NaN          NaN           NaN
# 748      -1.000000    -1.000000     -1.000000
# 804      -1.000000    -1.000000     -1.000000
# 873      -0.326923    -0.431193     -0.167507
# 915      -1.000000    -1.000000     -1.000000
# 924      -0.537500    -0.556818     -0.103518
# 1147           NaN          NaN           NaN

# %%
dataDict['troubleRate']
# Out:
#                   故障类型  ap_count      dhcp    portal  prelogin     login  \
# hos_id
# 123               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 134               AP离线 -0.100000 -0.062921 -0.009404 -0.050633 -0.104839
# 188               AP离线 -0.142857  0.056235       NaN       NaN       NaN
# 195     webforward打点故障 -0.071429 -0.116183  0.000000  0.088235  0.063492
# 201               AP离线 -0.156250 -0.123077       NaN       NaN       NaN
# 274               AP离线 -0.245902 -0.081560       NaN       NaN       NaN
# 317               AP离线 -0.257143 -0.126827 -0.123389 -0.087798 -0.083739
# 321               网关离线 -1.000000 -1.000000       NaN       NaN       NaN
# 451               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 608               AP离线 -0.388889 -0.110358 -0.147877 -0.196755 -0.207127
# 609               AP离线 -0.100000  0.111782       NaN       NaN       NaN
# 634               AP离线 -0.111111  0.005348       NaN       NaN       NaN
# 720               AP离线 -0.125000  0.010381       NaN       NaN       NaN
# 748               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 804               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 873             硬件放行故障  0.000000 -0.316742 -0.363971 -0.292517 -0.365079
# 915               网关离线 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 924      未知  dhcp<-0.4  0.000000 -0.505643 -0.510972 -0.519231 -0.536458
# 1147              AP离线 -0.575758 -0.477465       NaN       NaN       NaN
#
#         webforward  hardforward  forward_rate
# hos_id
# 123      -1.000000    -1.000000     -1.000000
# 134      -0.129630    -0.183486     -0.128660
# 188            NaN          NaN           NaN
# 195      -0.948276          NaN           NaN
# 201            NaN          NaN           NaN
# 274            NaN          NaN           NaN
# 317      -0.079402    -0.133850     -0.008042
# 321            NaN          NaN           NaN
# 451      -1.000000    -1.000000     -1.000000
# 608      -0.192837    -0.184896     -0.083784
# 609            NaN          NaN           NaN
# 634            NaN          NaN           NaN
# 720            NaN          NaN           NaN
# 748      -1.000000    -1.000000     -1.000000
# 804      -1.000000    -1.000000     -1.000000
# 873      -0.326923    -0.431193     -0.167507
# 915      -1.000000    -1.000000     -1.000000
# 924      -0.537500    -0.556818     -0.103518
# 1147           NaN          NaN           NaN

# %%
from raw_data import RawData
from pre_process import DataClean as dc
from pre_process import DateData as dd
from data_analysis import Analysis
from data_merge import Merge
from storage import Storage
from report import Report
import numpy as np
from email_data import Mail


def uvMonitor(day = 1,cycle = 1,sql = True,excel = True ,report = True,mail = True):
    day1 = day
    cycle = cycle
    day2 = day1 + cycle*7
    
    #获取原始数据
    rawData_ = RawData(day1=day1, day2=day2)
    uvData = rawData_.getUvData()
    apData = rawData_.getApData()
    data400 = rawData_.get400Data()
    devInfo = rawData_.getDevInfo()
    hosInfo = rawData_.getHosInfo()

    #预处理
    cleanData = dc(uvData, apData)
    uvDataGood, apDataGood = cleanData.uvDataClean(), cleanData.apDataClean()
    dataData = dd(uvDataGood, apDataGood, day1=day1, day2=day2)
    uvDay1, uvDay2 = dataData.uvDay1Lite, dataData.uvDay2Lite

    #对比分析
    analData = Analysis(uvDay1, uvDay2)
    trouble, rate = analData.comparison()

    #数据合并
    mergeData = Merge(troubleHos=trouble, uvDay1=uvDay1, uvDay2=uvDay2,
                      rate=rate, data400=data400, devInfo=devInfo, hosInfo=hosInfo)
    allData = mergeData.allData()

    #存储
    saveData = Storage(data=allData, day=day1, cycle=cycle)
    saveData.toMySql()
    excelPath = saveData.toExcel()

    #生成报告
    reportData = Report(data=allData, day=day1, cycle=cycle)
    reportPath = reportData.makeReport()

    #发送邮件
    pathList = [excelPath, reportPath]
    mailData = Mail(pathList=pathList, day=day1, cycle=cycle)
    mailData.sendEmail()
    
def main():
    uvMonitor()

    
if __name__ == '__main__':
    main()
