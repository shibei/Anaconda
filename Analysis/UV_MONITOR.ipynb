# %%
import pymysql as psql
import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import datetime
import pymysql.cursors
from contextlib import contextmanager
import smtplib
import os
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email import encoders
from sqlalchemy import create_engine  
from docx import Document
from docx.shared import Inches

# %%
#使用上下文管理器来连接数据库的函数
@contextmanager
def connect(server):
    database = pymysql.connect(**server)
    yield database 
    database.close()

#在数据库中执行命令函数
def sqlAction(database,action):
    with database.cursor() as cursor:
        # 执行sql语句，进行查询
        cursor.execute(action)
        # 获取查询结果
        result = cursor.fetchall()
    # 没有设置默认自动提交，需要主动提交，以保存所执行的语句
    database.commit()
    return result

class SqlServer(object):  # 定义sqlServer类，用来连接到mysql获取数据
    """docstring for sqlServer"""
    #   server的数据结构示例
    # {"server": { #数据库信息
    #     'host': 'localhost',#ip地址
    #     'port': 3066,端口号
    #     'user': 'root',用户名
    #     'password': 'password'密码,
    #     'db': 'db',数据库名称
    #     'charset': 'utf8mb4',编码方式
    #     'cursorclass': pymysql.cursors.DictCursor
    # },
    #     "comm": {命令描述和要执行的命令
    #     'apData': "SELECT * FROM `ap_count`",
    #     'uvData': "SELECT * FROM `funnel_model2`"
    # }}

    def __init__(self,server):
        self.server = server["server"]
        self.sqlComm = server["comm"]
    
#     只执行一条命令
    def getOneData(self,key):
        server = self.server
        with connect(server) as database:
            result = sqlAction(database,self.sqlComm[key])
#             print(result)
        try:
            df = pd.DataFrame(result)
        except:
            df =pd.DataFrame([])
        return df
    
#     执行所有命令
    def getAllData(self):
        server = self.server
        sqlDatas ={}
        with connect(server) as database:
            for key in self.sqlComm:
                result = pd.DataFrame(sqlAction(database,self.sqlComm[key]))
                sqlDatas[key] = result
        return sqlDatas

# 获取x天之前的日期
def getDate(x):
    today = datetime.date.today()
    oneday = datetime.timedelta(days=x)
    day = today-oneday
    return day

#重新排序列
def reColumns(df, columns=['hos_id','dhcp', 'portal', 
                           'prelogin', 'login', 'webforward', 
                           'hardforward', 'log_date']):
    for x in range(len(columns)):
        p = df.pop(columns[x])
        df.insert(x, columns[x], p)
    return df

def get400Data(day,cycle,path = r'/var/400data/400.xlsx'):
    day1 = getDate(day)
    day2 = getDate(day+cycle)
    data400 = pd.read_excel(path)
    data400.columns = data400.loc[0].values.tolist()
    data400 = data400.drop(0)
    data4001 = pd.DataFrame([])
    data4001[[r'报修日期', r'解决问题日期']] = data400[
        [r'报修日期', r'解决问题日期']].dropna().astype('datetime64[ns]')
    data4001[[r'医院名称', r'报修问题', r'解决方式', r'解决人']] = data400[
        [r'医院名称', r'报修问题', r'解决方式', r'解决人']]
    return data4001[(data4001[r'报修日期'] >= day2) & (data4001[r'报修日期'] <= day1)]

#从文件中获得DB信息
def getDbInfo(file,sheet):
    serverDf =np.transpose(pd.read_excel(file,sheet))
    serverCommList = {}
    for server in serverDf:
        serverComm = {"comm":{}}
        serverDict = serverDf[server].to_dict()
        serverDict['password'] = str(serverDict['password'])
        serverDict['charset'] = 'utf8mb4'
        serverDict['cursorclass'] = pymysql.cursors.DictCursor
        serverComm["server"] =serverDict
        serverCommList[server] = serverComm
    return serverCommList

#从文件中获得sender信息
def emailSender(file,sheet):
    senderDf = np.transpose(pd.read_excel(file,sheet))
    senderList = {}
    for sender in senderDf:
        senderDict = senderDf[sender].to_dict()
        senderList[sender] = senderDict
    return senderList

#从文件中获得receiver信息
def emailReceiver(file,sheet):
    receiveDf = pd.read_excel(file,sheet)
    return receiveDf['receive'].tolist()

# %%
def getRawData(day, cycle):

    day0 = str(getDate(0))
    day1 = str(getDate(day))
    day2 = str(getDate(day+cycle))
    dayX = '2017-09-26'

    DbList = getDbInfo(r'/root/ipython/user_list.xlsx',r'db_user')
    uvBase = DbList['uvBase']
    hosBase = DbList['hosBase']
    devBase = DbList['devBase']

    totalInfoFields = json.dumps(['HosID', 'Hospital', 'Value',
                                  'CurrentBroadbandBandwidth', 'GatewayVendor',
                                  'ApVendor', 'ApType', 'GWID']).strip('[').strip(']').replace('"', '')

    devInfoFields = json.dumps(['clock', 'cpuUsed', 'downSpeed',
                                'gwid', 'starttimeLong',
                                'status', 'wanIp']).strip('[').strip(']').replace('"', '')

    uvBase['comm']['apData'] = "SELECT * FROM `ap_count` WHERE \
    `log_date` = '%s' OR `log_date` = '%s' ORDER BY \
    `log_date` DESC" % (day2, day1)

    uvBase['comm']['uvData'] = "SELECT * FROM `funnel_model2` WHERE \
    `log_date` = '%s' OR `log_date` = '%s' ORDER BY \
    `log_date` DESC" % (day2, day1)

    devBase['comm']['devInfo'] = "SELECT %s FROM `dev_info` \
    WHERE `date` = '%s' ORDER BY `clock` DESC LIMIT 0, 1000" % (devInfoFields, dayX)

    hosBase['comm']['totalInfo'] = "SELECT %s FROM `TOTAL_INFO_T_%s`" % (
        totalInfoFields, day1.replace('-', ''))

    uvDatabase, hosDatabase, devDatabase = SqlServer(
        uvBase), SqlServer(hosBase), SqlServer(devBase)

    uvDataRaw, apDataRaw, hosInfoRaw, devInfoRaw = uvDatabase.getOneData('uvData'), uvDatabase.getOneData(
        'apData'), hosDatabase.getOneData('totalInfo'), devDatabase.getOneData('devInfo')

    data400Raw = get400Data(day, cycle)
    return uvDataRaw, apDataRaw,hosInfoRaw, devInfoRaw, data400Raw

# %%
# 清洗数据
def dataClean(uvData,apData):
    if len(uvData) > 0:
        reColumns(uvData)
        uvData = uvData.replace('\\N', 0).fillna(0).sort_values(
            by='log_date', ascending=False).reset_index(drop=True)
        uvDataGood = uvData[['hos_id','dhcp', 'portal', 'prelogin',
                             'login', 'webforward', 'hardforward']].astype('int32')
        uvDataGood['log_date'] = uvData['log_date'].astype('datetime64[ns]')
        uvDataGood['forward_rate'] = uvDataGood['hardforward']/uvDataGood['dhcp']
        uvDataLite = uvDataGood.drop(
            ['portal', 'prelogin', 'login', 'webforward'], axis=1)
    else:
        uvDataGood = uvData
        
    if len(apData) > 0:
        apData = apData.replace(['福建','安徽','福建省','安徽省',''],np.nan).dropna()
        apDataGood = apData[['hos_id','ap_count']].astype('int64')
        apDataGood['log_date'] = apData['log_date'].astype('datetime64[ns]')
    else:
        apDataGood = apData
    return uvDataGood,apDataGood

# %%
# 提取n天和n+r天前的数据
def getDateData(uvData, apData, day=1, cycle=7):
    d1 = day
    d2 = d1+cycle
    day1 = getDate(d1)
    day2 = getDate(d2)
    if len(uvData) >0:
        uvDay1 = uvData[uvData['log_date'] == day1].reset_index(
            drop=True).set_index('hos_id').drop('log_date', axis=1)
        uvDay2 = uvData[uvData['log_date'] == day2].reset_index(
            drop=True).set_index('hos_id').drop('log_date', axis=1)
    
    if len(apData) >0:
        apDay1 = apData[apData['log_date'] == day1].set_index(
            'hos_id').drop('log_date', axis=1)
        apDay2 = apData[apData['log_date'] == day2].set_index(
            'hos_id').drop('log_date', axis=1)
        uvDay1 = pd.merge(uvDay1, apDay1, left_index=True,
                          right_index=True, how='left')
        uvDay2 = pd.merge(uvDay2, apDay2, left_index=True,
                          right_index=True, how='left')
#     print(uvDay1.index, uvDay2.index)
    allHosid = np.union1d(uvDay1.index, uvDay2.index)
    uvDay1 = uvDay1.reindex(allHosid, fill_value=0)
    uvDay2 = uvDay2.reindex(allHosid, fill_value=0)
    
    if len(apData) >0:
        uvDay1.insert(0, 'ap_count', uvDay1.pop('ap_count'))
        uvDay2.insert(0, 'ap_count', uvDay2.pop('ap_count'))
    
    uvDay2Lite = uvDay2[uvDay2['dhcp'] > 200]
    uvDay1Lite = uvDay1.reindex(uvDay2Lite.index)
    return uvDay1, uvDay2, uvDay1Lite, uvDay2Lite

# %%
#依靠经验值来构建的决策树

def decisionTree(data,rawData,apLimit = -0.1,forwardLimit = -0.4 ,globalLimit = -0.4):
    index = data.index #获得目录
    splitTerm0 = data[index[0]] <= globalLimit #分裂条件0
    if len(index) > 1:
        splitTerm1 = data[index[1]] <= 0.5*globalLimit #分裂条件1
    
    #"""决策树第一层"""
    #如果data的第一行索引名为'ap_count',并且第一行值等于-1，那么返回‘网关离线’。（AP全掉了）
    if index[0] == 'ap_count' and data[index[0]] == -1:
        return '网关离线' 
    
    #如果data的第一行索引名为'ap_count',并且第一行值小于apLimi同时不等于-1，那么返回‘AP离线’。（AP掉了一部分）
    elif index[0] == 'ap_count' and data[index[0]] <= apLimit and data[index[0]] != -1:
        return 'AP离线'
    
    #如果data的第一行索引名为'ap_count',并且第一行值大于apLimit，那么data去除第一行，其他参数保持不变，进行递归
    #（如果AP数量没有下降，那么进行下一步判断）
    elif index[0] == 'ap_count' and data[index[0]] > apLimit:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第二层"""
    #如果data的第一行索引名为'dhcp',并且同时满足分裂条件0和1，那么返回'未知'。（莫名其妙的DHCP数就下降了）
    elif index[0] == 'dhcp' and splitTerm0 and splitTerm1:
        return '未知  '+index[0]+'<'+str(globalLimit)
    
    #如果data的第一行索引名为'dhcp',并且满足分裂条件0,不满足分裂条件1，那么返回'DHCP统计错误'。（只有DHCP数下降了）
    elif index[0] == 'dhcp' and splitTerm0 and not splitTerm1:
        return 'DHCP统计错误'
    
    #如果data的第一行索引名为'dhcp',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果DHCP数没有下降，那么进行下一步判断）
    elif index[0] == 'dhcp' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第三层"""
    #如果data的第一行索引名为'portal',并且同时满足分裂条件0和1，那么返回'重定向故障'。（莫名其妙的portal数就下降了）
    elif index[0] == 'portal' and splitTerm0 and splitTerm1:
        return '重定向故障'
    
    #如果data的第一行索引名为'portal',并且满足分裂条件0不满足分裂条件1，那么返回'portal打点故障'。（只有portal数下降了）
    elif index[0] == 'portal' and splitTerm0 and not splitTerm1:
        return 'portal打点故障'
    
    #如果data的第一行索引名为'portal',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果portal数没有下降，那么进行下一步判断）
    elif index[0] == 'portal' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第四层"""
    #如果data的第一行索引名为'prelogin',并且同时满足分裂条件0和1，那么返回'带宽负载较高（疑似）'。（预登陆人数变少了，可能是带宽造成的）
    elif index[0] == 'prelogin' and splitTerm0 and splitTerm1:
        return '带宽负载较高（疑似）'
    
    #如果data的第一行索引名为'prelogin',并且满足分裂条件0不满足分裂条件1，那么返回'prelogin打点故障'。（只有prelogin数下降了）
    elif index[0] == 'prelogin' and splitTerm0 and not splitTerm1:
        return 'prelogin打点故障'
    
    #如果data的第一行索引名为'prelogin',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果prelogin数没有下降，那么进行下一步判断）
    elif index[0] == 'prelogin' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    

    #"""决策树第五层"""
    #如果data的第一行索引名为'login',并且同时满足分裂条件0和1，那么返回'未知'。（莫名其妙的login数就变少了）
    elif index[0] == 'login' and splitTerm0 and splitTerm1:
        return '未知'+index[0]+'<'+str(globalLimit)
    
    #如果data的第一行索引名为'login',并且满足分裂条件0不满足分裂条件1，那么返回'login打点故障'。（只有login数下降了）
    elif index[0] == 'login' and splitTerm0 and not splitTerm1:
        return 'login打点故障'
    
    #如果data的第一行索引名为'login',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果login数没有下降，那么进行下一步判断）
    elif index[0] == 'login' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第六层"""
    #如果data的第一行索引名为'webforward',并且同时满足分裂条件0和1，那么返回'web放行故障'。（莫名其妙的webforward数就变少了）
    elif index[0] == 'webforward' and splitTerm0 and splitTerm1:
        return 'web放行故障'
    
    #如果data的第一行索引名为'webforward',并且满足分裂条件0不满足分裂条件1，那么返回'webforward打点故障'。（只有webforward数下降了）
    elif index[0] == 'webforward' and splitTerm0 and not splitTerm1:
        return 'webforward打点故障'
    
    #如果data的第一行索引名为'webforward',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果webforward数没有下降，那么进行下一步判断）
    elif index[0] == 'webforward' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第七层"""
    #如果data的第一行索引名为'hardforward',并且满足分裂条件0，那么返回'硬件放行故障'。（莫名其妙的hardforward数就变少了）
    elif index[0] == 'hardforward' and splitTerm0:
        return '硬件放行故障'
    
    #如果data的第一行索引名为'hardforward',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果hardforward数没有下降，那么进行下一步判断）
    elif index[0] == 'hardforward' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第八层"""
    #如果data的第一行索引名为'forward_rate',并且不满足分裂条件0，那么返回'正常'。（正常情况）
    elif index[0] == 'forward_rate' and not splitTerm0:
        return '正常'
    
    #如果data的第一行索引名为'forward_rate',并且满足分裂条件0，那么赋值rawData到data，globalLimit - 0.05,其他参数保持不变，进行递归
    #（如果其他参数正常，只有forward_rate变少了，那么减小分裂系数，重新进行分析，）
    elif index[0] == 'forward_rate' and not splitTerm0:
        return decisionTree(rawData,rawData,apLimit,forwardLimit,globalLimit-0.05)

# %%
def analysis(day,cycle,apLimit = -0.1,forwardLimit = -0.4 ,globalLimit = -0.4):
    uvDataRaw, apDataRaw,hosInfoRaw, devInfoRaw, data400Raw = getRawData(day, cycle)
    uvDataGood,apDataGood = dataClean(uvDataRaw,apDataRaw)
    uvDay1, uvDay2, uvDay1Lite,uvDay2Lite = getDateData(uvDataGood,apDataGood,day,cycle)
    rate =((uvDay1Lite.reindex(uvDay2Lite.index).fillna(0)-uvDay2Lite)/uvDay2Lite)
    troubleList = {}
    for hos in rate.index:
        trouble = decisionTree(rate.loc[hos],rate.loc[hos],-0.1,-0.4,-0.4)
        troubleList[hos] = trouble
    statusSeries = pd.Series(troubleList)
    troubleHos = statusSeries[statusSeries !='正常']
    troubleDf = pd.DataFrame(troubleHos,columns=['故障类型'])
    troubleDf.insert(0,'hos_id',troubleDf.index)
    troubleRate =pd.merge(troubleDf,rate,left_on='hos_id',right_index=True)
    troubleUvDay1=pd.merge(troubleDf,uvDay1,left_on='hos_id',right_index=True)
    troubleUvDay2 =pd.merge(troubleDf,uvDay2,left_on='hos_id',right_index=True)
    troubleTotal = mergeDf(troubleDf,hosInfoRaw, devInfoRaw, data400Raw)[[
        'hos_id',r'故障类型',r'AP型号',r'AP品牌',r'GWID(网关ID)','网关品牌',
        '医院名称','医院级别','status','报修日期','解决问题日期','报修问题',
        '解决方式','解决人']]
    troubleTotal[['报修日期','解决问题日期']].astype('datetime64[ns]')
    if 0 in troubleTotal['hos_id']:troubleTotal = troubleTotal.drop(0)
    troubleTotal = troubleTotal.set_index('hos_id',drop = False)
    troubleInfo = {
        'troubleTotal':troubleTotal,
        'troubleRate':troubleRate,
        'troubleUvDay1' :troubleUvDay1,
        'troubleUvDay2' : troubleUvDay2
    }
    return troubleInfo

# %%
def mergeDf(troubleDf,hosInfoRaw, devInfoRaw, data400Raw):
    hosInfoRaw.columns = hosInfoRaw.loc[0]
    hosInfoRaw = hosInfoRaw.set_index('HosID')
    hosInfoRaw = hosInfoRaw.reindex(hosInfoRaw.index.dropna()).drop('HosID')
    hosInfoRaw.index = hosInfoRaw.index.astype('int32')
    devInfo = devInfoRaw[devInfoRaw['clock'] == devInfoRaw['clock'].loc[0]]
    troubleDfTotal = pd.merge(troubleDf,hosInfoRaw,left_on='hos_id',right_index=True,how='left')
    troubleDfTotal = pd.merge(troubleDfTotal,devInfo,left_on=r'GWID(网关ID)',right_on='gwid',how='left')
    troubleDfTotal = pd.merge(troubleDfTotal,data400Raw,left_on=r'医院名称',right_on='医院名称',how='left')
    return troubleDfTotal

# %%
def chineseNumber(x):
    num=['零','一','二','三','四','五','六','七','八','九']  
    return num[x]

def englishNumber(x):
    num=['ZERO','ONE','TWO','THREE','FOUR','FIVE','SIX','SEVEN','EIGHT','NINE','TEN']  
    return num[x]

# %%
def sendEmail(pathList,day,cycle):
    senderList = emailSender(r'/root/ipython/user_list.xlsx',r'email_sender')
    receiverList = emailReceiver(r'/root/ipython/user_list.xlsx',r'email_receive')
    user = senderList['qq']['user']
    pwd = senderList['qq']['password']
    to = ','.join(receiverList)
    msg = MIMEMultipart()
    title =  '%s周对比分析_%s' % (chineseNumber(cycle),str(getDate(day)))
    message =  '附件为%s的%s周对比分析结果' %  (str(getDate(day)),chineseNumber(cycle))
    msg['Subject'] = title
#     msg['From'] = r'UV_MONITOR'
    content1 = MIMEText(message, 'plain', 'utf-8')
    msg.attach(content1)
    for path in pathList:
        attfile = path
        basename = os.path.basename(attfile)
        fp = open(attfile, 'rb')
        att = MIMEText(fp.read(), 'base64', 'utf-8')
        att["Content-Type"] = 'application/octet-stream'
        att.add_header('Content-Disposition', 'attachment',filename=('gbk', '', basename))
        encoders.encode_base64(att)
        msg.attach(att)
    #-----------------------------------------------------------
    s = smtplib.SMTP('smtp.qq.com')
    s.login(user, pwd)
    s.sendmail(user, to, msg.as_string())
    s.close()

def MySql(troubleInfo,day=1,cycle=1):
    outPutServer = getDbInfo(r'/root/ipython/user_list.xlsx',r'db_user')['devBase']['server']
    engine = create_engine('mysql+pymysql://%s:%s@%s:%d/%s'%(outPutServer['user'],
                                                             outPutServer['password'],
                                                             outPutServer['host'],
                                                             outPutServer['port'],
                                                             outPutServer['db']),connect_args={'charset':'utf8'})
    for trouble in troubleInfo:
        troubleInfo[trouble]['date'] = getDate(day)
        troubleInfo[trouble].to_sql(name='%d_TROUBLE_%s_ON_%s_WEEK'%(cycle,str.upper(trouble[7:]),
                                                              englishNumber(cycle)),
                                con=engine,if_exists='append',index=False)

# %%
def output(day=1, cycle=1,toEmail = True,toSql=True):
    Path = r'/root/ipython/UV分析结果/%s周对比/%s周对比_%s.xlsx' % (chineseNumber(cycle),chineseNumber(cycle), str(getDate(day)))
    day2 = cycle*7
    writer = pd.ExcelWriter(Path)
    troubleInfo= analysis(day, day2)
    pathList = []
    for x in troubleInfo:
        troubleInfo[x].to_excel(writer,x)
        pathList.append(Path)
    writer.save()
    if toEmail:
        sendEmail(pathList,day,cycle)
    if toSql:
        toMySql(troubleInfo,day,cycle)

# %%
def main():
    output(1,1)
    output(1,4,toEmail=False)

# %%
if __name__ == '__main__':
    main()

# %%
def reconfigOut(t):
#     t = analysis(1,1*7)
    out = {}
    for id in t['troubleTotal'].drop_duplicates('hos_id')['hos_id']:
        out[id] = {}
        out[id]['Total'] = pd.DataFrame(t['troubleTotal'].drop_duplicates('hos_id').loc[id])
        a1 = np.transpose(pd.DataFrame(t['troubleUvDay1'].loc[id][2:]))
        a1 = a1.append(t['troubleUvDay2'].loc[id][2:])
        a1 = a1.append(t['troubleRate'].loc[id][2:])
        a1.insert(0,column='title',value=['troubleUvDay1','troubleUvDay2','troubleRate'])
        a1 = a1.set_index('title')
        out[id]['Data'] = a1
    return out

# %%
def addTab(df):
    df = df.fillna('nan')
    rowsLen = len(df)
    columnsLen = len(df.columns)
    columns = df.columns
    table = document.add_table(rows=1, cols=columnsLen+1)
    hdr_cells = table.rows[0].cells
    for t in range(columnsLen) :
        hdr_cells[t+1].text = str(columns[t])
    for r in range(rowsLen):
        row = df.loc[df.index[r]].values
        row_cells = table.add_row().cells
        row_cells[0].text = str(df.index[r])
        for t in range(columnsLen) :
            if str(df.index[r]) == 'troubleRate' or t == 7:
                row_cells[t+1].text = str(row[t]*100)[:4]+r'%'
            else:
                row_cells[t+1].text = str(row[t])

# %%
out = analysis(1,1*7)

# %%
data = reconfigOut(out)

# %%
out['troubleTotal']
# Out:
#         hos_id           故障类型      AP型号    AP品牌        GWID(网关ID)     网关品牌  \
# hos_id
# 118        118           AP离线      R300  Ruckus      001631f1b4dc  ABLOOMY
# 137        137           AP离线   IAP-103   Aruba  9997b3caa00E5243       寰创
# 148        148           网关离线  ZK-W620D      爱快  61060300FF0E4E37    寰创+爱快
# 156        156           AP离线   IAP-103   Aruba  61060300FF0E4EBF       寰创
# 173        173           网关离线      R300  Ruckus      001631f47a92  ABLOOMY
# 317        317           AP离线   IAP-103   Aruba  61060300FF0CBCCE       寰创
# 321        321           网关离线   IAP-103   Aruba      001631f47b22  ABLOOMY
# 518        518     带宽负载较高（疑似）    N200-单      寰创  65ab0eb7520D484F       寰创
# 547        547           网关离线      N200      寰创  61060300FF0C9542       寰创
# 572        572           网关离线   IAP-103   Aruba      001631f895a6  ABLOOMY
# 674        674           网关离线      R300  Ruckus      0082ae834beb  ABLOOMY
# 681        681       DHCP统计错误      R300  Ruckus      001631f1b764  ABLOOMY
# 727        727           网关离线      R300  Ruckus      000babf02918  ABLOOMY
# 744        744           AP离线      N200      寰创  61060300FF0C11A6       寰创
# 819        819           网关离线    N200-双      寰创  f6059feba20CBCBE       寰创
# 862        862           AP离线      N200      寰创  61060300FF0C2F1A       寰创
# 864        864           AP离线      N200      寰创  61060300FF0C2EF2       寰创
# 970        970           AP离线      R300  Ruckus      001631f1b724  ABLOOMY
# 1107      1107  未知  dhcp<-0.4      R300  Ruckus  61060300FF107682       寰创
# 1134      1134           AP离线   IAP-103   Aruba      001631f1c7bc  ABLOOMY
# 1311      1311           网关离线   IAP-103   Aruba      001631f867e6  ABLOOMY
#
#                                 医院名称    医院级别 status       报修日期     解决问题日期  \
# hos_id
# 118                         青羊区妇幼保健院   C级,一线      0        NaT        NaT
# 137                    深圳市妇幼保健院（临床部）      S级    NaN        NaT        NaT
# 148                         枣庄市妇幼保健院      B级    NaN 2017-11-09 2017-11-09
# 156                         潍坊市妇幼保健院   A级,三线    NaN        NaT        NaT
# 173     锦江区妇幼保健院(光华街院区) （ 成都锦欣妇产科医院）      B级      1        NaT        NaT
# 317                           郑州大桥医院      B级    NaN        NaT        NaT
# 321                         三门峡市中心医院      B级      1        NaT        NaT
# 518                         合阳县妇幼保健院      B级    NaN 2017-11-06 2017-11-06
# 547                         金华市妇幼保健院      B级    NaN 2017-11-03 2017-11-03
# 572                         中牟县妇幼保健院      F级      1 2017-11-06 2017-11-06
# 674                        牡丹江市妇幼保健院      B级      1        NaT        NaT
# 681                     中国五冶集团有限公司医院  B级,一线,      1 2017-11-09 2017-11-09
# 727                         富阳市妇幼保健院      A级      1        NaT        NaT
# 744                       慈溪市庵东中心卫生院      F级    NaN        NaT        NaT
# 819                         平阳县妇幼保健院   F级,二线    NaN        NaT        NaT
# 862                         北镇市妇幼保健院      C级    NaN        NaT        NaT
# 864                         福州市妇幼保健院      C级    NaN        NaT        NaT
# 970                           德安县中医院    DEAD      1        NaT        NaT
# 1107                          大丰市中医院      F级    NaN        NaT        NaT
# 1134                     福建省长汀县妇幼保健院      B级      1        NaT        NaT
# 1311                     东昌府区妇幼保健院分院      B级      0        NaT        NaT
#
#                                报修问题     解决方式  解决人
# hos_id
# 118                             NaN      NaN  NaN
# 137                             NaN      NaN  NaN
# 148                              离线    需报修外网   黄悦
# 156                             NaN      NaN  NaN
# 173                             NaN      NaN  NaN
# 317                             NaN      NaN  NaN
# 321                             NaN      NaN  NaN
# 518                              离线  老师把电源拔了  张晓超
# 547     老师反映现在总院的网络也无法使用了，询问是不是续费问题  宽带到期待开通   黄悦
# 572                              离线    已报修外网   黄悦
# 674                             NaN      NaN  NaN
# 681                          安排设备拆除      NaN  张晓超
# 727                             NaN      NaN  NaN
# 744                             NaN      NaN  NaN
# 819                             NaN      NaN  NaN
# 862                             NaN      NaN  NaN
# 864                             NaN      NaN  NaN
# 970                             NaN      NaN  NaN
# 1107                            NaN      NaN  NaN
# 1134                            NaN      NaN  NaN
# 1311                            NaN      NaN  NaN

# %%
total = out['troubleTotal'][[r'故障类型',r'医院名称',r'医院级别',r'报修问题']].drop_duplicates(r'医院名称')

# %%
total
# Out:
#                  故障类型              医院名称   医院级别  \
# hos_id
# 55              重定向故障          霸州市妇幼保健院  B级,三线
# 57              重定向故障          承德市妇幼保健院     B级
# 58              重定向故障          成华区妇幼保健院     B级
# 62              重定向故障          文安县妇幼保健院     F级
# 64              重定向故障          平谷区妇幼保健院     B级
# 67              重定向故障          延庆县妇幼保健院     B级
# 70      未知  dhcp<-0.4          通州区妇幼保健院     S级
# 71              重定向故障        东城区第二妇幼保健院     C级
# 74              重定向故障          石景山妇幼保健院     C级
# 78              重定向故障        东城区第一妇幼保健院     B级
# 79              重定向故障          唐山市妇幼保健院     A级
# 80              重定向故障          昌平区妇幼保健院     A级
# 81              重定向故障          鹿泉市妇幼保健院     B级
# 82               AP离线          沧州市妇幼保健院     A级
# 85               AP离线          丰润区妇幼保健院     C级
# 104             重定向故障          绵竹市妇幼保健院     C级
# 114             重定向故障         青白江区妇幼保健院     B级
# 118             重定向故障          青羊区妇幼保健院     C级
# 120             重定向故障          芜湖市妇幼保健院     B级
# 129             重定向故障          山东省妇幼保健院     C级
# 133             重定向故障       济宁市市中区妇幼保健院     B级
# 144             重定向故障          新密市妇幼保健院     B级
# 145             重定向故障          曲阜市妇幼保健院     B级
# 152             重定向故障           郫县妇幼保健院     C级
# 154             重定向故障          武侯区妇幼保健院     B级
# 155              网关离线       胜利石油管理局胜利医院     B级
# 157             重定向故障          双流县妇幼保健院     B级
# 158             重定向故障          广元市妇幼保健院     B级
# 164              网关离线         二道江区妇幼保健院     C级
# 170              网关离线         梅河口市妇幼保健院     B级
# ...               ...               ...    ...
# 1095            重定向故障             上杭县医院     B级
# 1108            重定向故障           高邮市中医医院     B级
# 1120            重定向故障             连城县医院     B级
# 1134            重定向故障       福建省长汀县妇幼保健院     B级
# 1142       portal打点故障           海门市人民医院     B级
# 1144            重定向故障          成都西囡妇科医院     B级
# 1145            重定向故障          万安县妇幼保健院     F级
# 1147            重定向故障           吉安县人民医院     B级
# 1148       portal打点故障            吉安县中医院     B级
# 1149            重定向故障            万安县中医院     B级
# 1151            重定向故障          井冈山市人民医院     F级
# 1153            重定向故障          吉安市红十字医院     B级
# 1157       portal打点故障  泰和县妇幼保健院（妇女儿童医院）     B级
# 1165             AP离线        江西省永丰县人民医院     B级
# 1170            重定向故障            泰和县中医院     B级
# 1171            重定向故障           泰和县人民医院     B级
# 1176            重定向故障           井冈山市中医院     F级
# 1178            重定向故障          海盐县妇幼保健院     B级
# 1181             网关离线          淄博莲池妇婴医院  B级,三线
# 1184            重定向故障            黄山首康医院     B级
# 1216            重定向故障          鹤岗市妇幼保健院     B级
# 1221            重定向故障            霸州市中医院     B级
# 1223             AP离线            龙岩人民医院     B级
# 1237             AP离线          蕲春县妇幼保健院     F级
# 1271            重定向故障          固始县妇幼保健院     F级
# 1281            重定向故障   陕西省妇幼保健院（后宰门院区）     S级
# 1298            重定向故障         青岛市妇女儿童医院     A级
# 1303            重定向故障         萧山区第三人民医院   收费医院
# 1308            重定向故障   梅州市妇幼保健计划生育服务中心     B级
# 1311            重定向故障       东昌府区妇幼保健院分院     B级
#
#                                                      报修问题
# hos_id
# 55                                                    NaN
# 57                                                    NaN
# 58                                                    NaN
# 62                                                    NaN
# 64                                                    NaN
# 67                                                    NaN
# 70                           信号有的，验证页面跳不出，所有网络覆盖区域都是这样的情况
# 71                                                    NaN
# 74                                                    NaN
# 78                                                    NaN
# 79                                                    无信号
# 80                                                    NaN
# 81                                                    NaN
# 82                                                    NaN
# 85                                                    NaN
# 104                                                   NaN
# 114                                                   NaN
# 118                                                   NaN
# 120                                                   NaN
# 129                                                   NaN
# 133                                                   NaN
# 144                                                   NaN
# 145                                                   NaN
# 152                                                   NaN
# 154                                 住院楼5楼内科，信号是有的，连接页面跳不出
# 155                                                   NaN
# 157        调试183.221.119.3  183.221.119.1  255.255.255.0
# 158                                                   NaN
# 164                                                   NaN
# 170                                                   NaN
# ...                                                   ...
# 1095                                                  NaN
# 1108                                                  NaN
# 1120                                                  NaN
# 1134                                                  NaN
# 1142                                                  NaN
# 1144                                                  NaN
# 1145                                                  NaN
# 1147                                                  NaN
# 1148                                                  NaN
# 1149                                                  NaN
# 1151                                                  NaN
# 1153                                                  NaN
# 1157                                                  NaN
# 1165    门诊1楼，信号有的，连接页面跳不出，老师表示之前已经反映过多次，但网络至今还无法正常使用。希...
# 1170                                                  NaN
# 1171                          门诊部6楼护师站，信号有经常掉线，掉线之后就连接不上了
# 1176                                                  NaN
# 1178                                                  NaN
# 1181    电信公司工作人员联系老师，说今天要到医院拆机。老师来电询问具体情况，事情比较急希望相关工作人...
# 1184                                                  NaN
# 1216                                                  NaN
# 1221                                                  NaN
# 1223                                                  NaN
# 1237                                                  NaN
# 1271                                                  NaN
# 1281                                                  NaN
# 1298                  感染、门诊、急症信号很强，链接wif后没有跳转页面，希望工程师查看下。
# 1303                                                  NaN
# 1308                                                  NaN
# 1311                                                  NaN
#
# [174 rows x 4 columns]

# %%
document = Document()
#添加主标题
document.add_heading(r'每日分析——20171019', 0)
#添加主标题下的内容
p = document.add_paragraph('以下为20171019的故障分析报告。')
document.add_heading(r'总体概况', level=1)
addTab(total)
for hos in list(data.keys()) :
#         print(hos)
    hosname = data[hos]['Total'].loc['医院名称'].values[0]
    print(hosname)
    document.add_heading(hosname, level=1)
    document.add_heading('医院概况', level=2)
#         print(data[hos]['Total'])
#         print(data[hos]['Total'])
    addTab(data[hos]['Total'])
    document.add_heading('医院UV数据', level=2)
    addTab(data[hos]['Data'])
#         print(data[hos]['Data'])
    # document.add_paragraph('Intense quote', style='IntenseQuote')

#         document.add_paragraph(
#             'first item in unordered list', style='ListBullet'
#         )
    # document.add_paragraph(
    #     'first item in ordered list', style='ListNumber'
    # )

    # document.add_picture('image.bmp', width=Inches(1))
#     addTab(data[57]['Total'])
#     document.add_page_break()
    document.save('demo.docx')
# Out:
# 青羊区妇幼保健院
# 深圳市妇幼保健院（临床部）
# 枣庄市妇幼保健院
# 潍坊市妇幼保健院
# 锦江区妇幼保健院(光华街院区) （ 成都锦欣妇产科医院）
# 郑州大桥医院
# 三门峡市中心医院
# 合阳县妇幼保健院
# 金华市妇幼保健院
# 中牟县妇幼保健院
# 牡丹江市妇幼保健院
# 中国五冶集团有限公司医院
# 富阳市妇幼保健院
# 慈溪市庵东中心卫生院
# 平阳县妇幼保健院
# 北镇市妇幼保健院
# 福州市妇幼保健院
# 德安县中医院
# 大丰市中医院
# 福建省长汀县妇幼保健院
# 东昌府区妇幼保健院分院

# %%
data
# Out:
# {70: {'Data':               ap_count  dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0     0      0        0     0          0           0
#   troubleUvDay2       66  2920   2161     1686  1509       1235        1267
#   troubleRate         -1    -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.433904
#   troubleRate             -1  ,
#   'Total':                                       70
#   hos_id                                70
#   故障类型                                网关离线
#   AP型号                                N200
#   AP品牌                                  寰创
#   GWID(网关ID)              61060300FF0C6AFC
#   网关品牌                                  寰创
#   医院名称                            通州区妇幼保健院
#   医院级别                                  S级
#   status                               NaN
#   报修日期                 2017-10-27 00:00:00
#   解决问题日期               2017-10-27 00:00:00
#   报修问题        信号有的，验证页面跳不出，所有网络覆盖区域都是这样的情况
#   解决方式                                外网报修
#   解决人                                  张晓超},
#  74: {'Data':               ap_count       dhcp    portal prelogin     login webforward  \
#   title
#   troubleUvDay1       21        246       137       63        60         57
#   troubleUvDay2       21        229       209      106       104         96
#   troubleRate          0  0.0742358 -0.344498 -0.40566 -0.423077   -0.40625
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          53     0.215447
#   troubleUvDay2          94      0.41048
#   troubleRate      -0.43617    -0.475134  , 'Total':                       74
#   hos_id                74
#   故障类型          带宽负载较高（疑似）
#   AP型号                R300
#   AP品牌              Ruckus
#   GWID(网关ID)  001631f1baac
#   网关品牌             ABLOOMY
#   医院名称            石景山妇幼保健院
#   医院级别                  C级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  85: {'Data':                ap_count      dhcp    portal  prelogin    login webforward  \
#   title
#   troubleUvDay1         6       235       165       111       91         83
#   troubleUvDay2        13       413       321       213      167        147
#   troubleRate   -0.538462 -0.430993 -0.485981 -0.478873 -0.45509  -0.435374
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          79      0.33617
#   troubleUvDay2         137     0.331719
#   troubleRate     -0.423358    0.0134182  ,
#   'Total':                           85
#   hos_id                    85
#   故障类型                    AP离线
#   AP型号                    N200
#   AP品牌                      寰创
#   GWID(网关ID)  61060300FF0C11F6
#   网关品牌                      寰创
#   医院名称                丰润区妇幼保健院
#   医院级别                      C级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  155: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2       26  933    855      419   408        371         387
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.414791
#   troubleRate             -1  , 'Total':                      155
#   hos_id               155
#   故障类型                网关离线
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f895fa
#   网关品牌             ABLOOMY
#   医院名称         胜利石油管理局胜利医院
#   医院级别                  B级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  157: {'Data':               ap_count       dhcp     portal  prelogin     login webforward  \
#   title
#   troubleUvDay1       12        518        466        59        57         55
#   troubleUvDay2       12        538        480       186       184        156
#   troubleRate          0 -0.0371747 -0.0291667 -0.682796 -0.690217  -0.647436
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          47    0.0907336
#   troubleUvDay2         166      0.30855
#   troubleRate     -0.716867    -0.705936  ,
#   'Total':                                                        157
#   hos_id                                                 157
#   故障类型                                            带宽负载较高（疑似）
#   AP型号                                                  R300
#   AP品牌                                                Ruckus
#   GWID(网关ID)                                    00ab27f00234
#   网关品牌                                           ABLOOMY-中苗刷
#   医院名称                                              双流县妇幼保健院
#   医院级别                                                    B级
#   status                                                   1
#   报修日期                                   2017-10-25 00:00:00
#   解决问题日期                                 2017-10-25 00:00:00
#   报修问题        调试183.221.119.3  183.221.119.1  255.255.255.0
#   解决方式                                                   NaN
#   解决人                                                    陈志平},
#  188: {'Data':               ap_count      dhcp    portal  prelogin      login webforward  \
#   title
#   troubleUvDay1        5       433       139        96         98         67
#   troubleUvDay2        5       531       447       109        103         74
#   troubleRate          0 -0.184557 -0.689038 -0.119266 -0.0485437 -0.0945946
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          88     0.203233
#   troubleUvDay2          89     0.167608
#   troubleRate     -0.011236     0.212549  , 'Total':                      188
#   hos_id               188
#   故障类型          portal打点故障
#   AP型号                R300
#   AP品牌              Ruckus
#   GWID(网关ID)  001631f1b8a4
#   网关品牌             ABLOOMY
#   医院名称            眉山市妇幼保健院
#   医院级别                  B级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  202: {'Data':               ap_count      dhcp    portal prelogin     login webforward  \
#   title
#   troubleUvDay1        3       289       236      126       106         86
#   troubleUvDay2        3       550       456      315       279        233
#   troubleRate          0 -0.474545 -0.482456     -0.6 -0.620072  -0.630901
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          86     0.297578
#   troubleUvDay2         238     0.432727
#   troubleRate     -0.638655     -0.31232  ,
#   'Total':                          202
#   hos_id                   202
#   故障类型           未知  dhcp<-0.4
#   AP型号                 IAP-103
#   AP品牌                   Aruba
#   GWID(网关ID)  bb88c6f274E83919
#   网关品牌                  寰创-中苗刷
#   医院名称                定州市妇幼保健院
#   医院级别                      B级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  210: {'Data':               ap_count  dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0     0      0        0     0          0           0
#   troubleUvDay2       40  1176    781      542   391        324         326
#   troubleRate         -1    -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.277211
#   troubleRate             -1  , 'Total':                          210
#   hos_id                   210
#   故障类型                    网关离线
#   AP型号                    N200
#   AP品牌                      寰创
#   GWID(网关ID)  61060300FF0CBD6A
#   网关品牌                      寰创
#   医院名称               杭州市红十字会医院
#   医院级别                      B级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  297: {'Data':               ap_count       dhcp portal prelogin login webforward  \
#   title
#   troubleUvDay1        8        528      0        0     0          0
#   troubleUvDay2        8        537    417      174   169        155
#   troubleRate          0 -0.0167598     -1       -1    -1         -1
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1           0            0
#   troubleUvDay2           0            0
#   troubleRate           NaN          NaN  , 'Total':                      297
#   hos_id               297
#   故障类型               重定向故障
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f8672a
#   网关品牌             ABLOOMY
#   医院名称             梧州市工人医院
#   医院级别                  F级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  299: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2        8  944    804      321   311        277         275
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.291314
#   troubleRate             -1  , 'Total':                      299
#   hos_id               299
#   故障类型                网关离线
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f8b2d2
#   网关品牌             ABLOOMY
#   医院名称             桂林市人民医院
#   医院级别                  B级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  441: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2       58  892    854      477   470        419         437
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2      0.48991
#   troubleRate             -1  ,
#   'Total':                                                           441
#   hos_id                                                    441
#   故障类型                                                     网关离线
#   AP型号                                                     R300
#   AP品牌                                                   Ruckus
#   GWID(网关ID)                                       001631f4ca74
#   网关品牌                                                  ABLOOMY
#   医院名称                                                 日照市妇幼保健院
#   医院级别                                                    B级,四线
#   status                                                      1
#   报修日期                                      2017-10-31 00:00:00
#   解决问题日期                                    2017-10-31 00:00:00
#   报修问题        调试，58.58.181.68 58.58.181.1 255.255.255.0 219....
#   解决方式                                                      NaN
#   解决人                                                       陈志平},
#  449: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2       20  837    715      408   402        368         383
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.457587
#   troubleRate             -1  , 'Total':                      449
#   hos_id               449
#   故障类型                网关离线
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f8d7e2
#   网关品牌             ABLOOMY
#   医院名称            济宁市妇幼保健院
#   医院级别               B级,三线
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  568: {'Data':               ap_count       dhcp portal prelogin login webforward  \
#   title
#   troubleUvDay1       17       1104      0        0     0          0
#   troubleUvDay2       17       1009    936      377   352        318
#   troubleRate          0  0.0941526     -1       -1    -1         -1
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1           0            0
#   troubleUvDay2         308     0.305253
#   troubleRate            -1           -1  , 'Total':                      568
#   hos_id               568
#   故障类型               重定向故障
#   AP型号                R300
#   AP品牌              Ruckus
#   GWID(网关ID)  001631f4ca5c
#   网关品牌             ABLOOMY
#   医院名称             温县妇幼保健院
#   医院级别                  B级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  571: {'Data':               ap_count  dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0     0      0        0     0          0           0
#   troubleUvDay2       48  1092    841      636   501        414         406
#   troubleRate         -1    -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.371795
#   troubleRate             -1  , 'Total':                             571
#   hos_id                      571
#   故障类型                       网关离线
#   AP型号                    IAP-103
#   AP品牌                      Aruba
#   GWID(网关ID)     61060300FF0C957E
#   网关品牌                         寰创
#   医院名称                   威海市妇幼保健院
#   医院级别                      A级,三线
#   status                      NaN
#   报修日期        2017-10-31 00:00:00
#   解决问题日期      2017-10-31 00:00:00
#   报修问题                         调试
#   解决方式                        NaN
#   解决人                         陈志平},
#  662: {'Data':                 ap_count       dhcp    portal  prelogin     login webforward  \
#   title
#   troubleUvDay1         86       2668      1564       598       586        507
#   troubleUvDay2         87       2464      2241       915       879        800
#   troubleRate   -0.0114943  0.0827922 -0.302097 -0.346448 -0.333333   -0.36625
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1         487     0.182534
#   troubleUvDay2         769     0.312094
#   troubleRate      -0.36671    -0.415132  ,
#   'Total':                             662
#   hos_id                      662
#   故障类型                       None
#   AP型号                       R300
#   AP品牌                     Ruckus
#   GWID(网关ID)         001631f47ae0
#   网关品牌                    ABLOOMY
#   医院名称                   九江市妇幼保健院
#   医院级别                         A级
#   status                        1
#   报修日期        2017-10-31 00:00:00
#   解决问题日期      2017-10-31 00:00:00
#   报修问题          有信号，验证页面跳不出网络无法使用
#   解决方式           拨号宽带NAT数问题  无法解决
#   解决人                         陈志平},
#  682: {'Data':               ap_count       dhcp    portal   prelogin      login webforward  \
#   title
#   troubleUvDay1        4        197       215         57         55         52
#   troubleUvDay2        5        214       247         59         59         53
#   troubleRate       -0.2 -0.0794393 -0.129555 -0.0338983 -0.0677966 -0.0188679
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          52     0.263959
#   troubleUvDay2          48     0.224299
#   troubleRate     0.0833333     0.176819  , 'Total':                      682
#   hos_id               682
#   故障类型                AP离线
#   AP型号                R300
#   AP品牌              Ruckus
#   GWID(网关ID)  001631f1b414
#   网关品牌             ABLOOMY
#   医院名称              成都金沙医院
#   医院级别                DEAD
#   status                 0
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  687: {'Data':                ap_count      dhcp    portal  prelogin    login webforward  \
#   title
#   troubleUvDay1        11       263       275       108      101         92
#   troubleUvDay2        42       849       780       329      316        116
#   troubleRate   -0.738095 -0.690224 -0.647436 -0.671733 -0.68038  -0.206897
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          81     0.307985
#   troubleUvDay2         270     0.318021
#   troubleRate          -0.7   -0.0315589  , 'Total':                      687
#   hos_id               687
#   故障类型                AP离线
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f1b3c8
#   网关品牌             ABLOOMY
#   医院名称            郴州市妇幼保健院
#   医院级别                  B级
#   status                 1
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  829: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2        2  560    415      251   220        180         181
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.323214
#   troubleRate             -1  , 'Total':                          829
#   hos_id                   829
#   故障类型                    网关离线
#   AP型号                 IAP-103
#   AP品牌                   Aruba
#   GWID(网关ID)  61060300FF0CA3C1
#   网关品牌                      寰创
#   医院名称               德清县第三人民医院
#   医院级别                      B级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  862: {'Data':               ap_count      dhcp    portal  prelogin     login webforward  \
#   title
#   troubleUvDay1        9       280       209       135       119        106
#   troubleUvDay2       12       331       258       167       154        133
#   troubleRate      -0.25 -0.154079 -0.189922 -0.191617 -0.227273  -0.203008
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1         110     0.392857
#   troubleUvDay2         131      0.39577
#   troubleRate     -0.160305  -0.00736096  ,
#   'Total':                          862
#   hos_id                   862
#   故障类型                    AP离线
#   AP型号                    N200
#   AP品牌                      寰创
#   GWID(网关ID)  61060300FF0C2F1A
#   网关品牌                      寰创
#   医院名称                北镇市妇幼保健院
#   医院级别                      C级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  873: {'Data':               ap_count      dhcp    portal  prelogin     login webforward  \
#   title
#   troubleUvDay1        9         6         3         1         2          0
#   troubleUvDay2       15       321       211       146       133        117
#   troubleRate       -0.4 -0.981308 -0.985782 -0.993151 -0.984962         -1
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1           0            0
#   troubleUvDay2         106     0.330218
#   troubleRate            -1           -1  ,
#   'Total':                          873
#   hos_id                   873
#   故障类型                    AP离线
#   AP型号                    N200
#   AP品牌                      寰创
#   GWID(网关ID)  958be6f5780D4847
#   网关品牌                      寰创
#   医院名称              温岭市温西中心卫生院
#   医院级别                      F级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN},
#  898: {'Data':               ap_count     dhcp    portal  prelogin     login webforward  \
#   title
#   troubleUvDay1        2      153       114        35        34         32
#   troubleUvDay2        2      219       212        93        91         82
#   troubleRate          0 -0.30137 -0.462264 -0.623656 -0.626374  -0.609756
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1          26     0.169935
#   troubleUvDay2          86     0.392694
#   troubleRate     -0.697674    -0.567259  , 'Total':                      898
#   hos_id               898
#   故障类型               重定向故障
#   AP型号                N200
#   AP品牌                  寰创
#   GWID(网关ID)  00F3D20011E5
#   网关品牌         ABLOOMY-爱快刷
#   医院名称         台州市椒江区妇幼保健所
#   医院级别               F级,二线
#   status               NaN
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  1181: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2       44  935    874      547   539        488         503
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.537968
#   troubleRate             -1  ,
#   'Total':                                                          1181
#   hos_id                                                   1181
#   故障类型                                                     网关离线
#   AP型号                                                     R300
#   AP品牌                                                   Ruckus
#   GWID(网关ID)                                       001631f98a12
#   网关品牌                                                  ABLOOMY
#   医院名称                                                 淄博莲池妇婴医院
#   医院级别                                                    B级,三线
#   status                                                      1
#   报修日期                                      2017-10-27 00:00:00
#   解决问题日期                                    2017-10-27 00:00:00
#   报修问题        电信公司工作人员联系老师，说今天要到医院拆机。老师来电询问具体情况，事情比较急希望相关工作人...
#   解决方式                                                      已联系
#   解决人                                                       刘运柱},
#  1304: {'Data':               ap_count dhcp portal prelogin login webforward hardforward  \
#   title
#   troubleUvDay1        0    0      0        0     0          0           0
#   troubleUvDay2       12  232    213      121   119        100         102
#   troubleRate         -1   -1     -1       -1    -1         -1          -1
#
#                 forward_rate
#   title
#   troubleUvDay1            0
#   troubleUvDay2     0.439655
#   troubleRate             -1  ,
#   'Total':                                           1304
#   hos_id                                    1304
#   故障类型                                      网关离线
#   AP型号                                   IAP-103
#   AP品牌                                     Aruba
#   GWID(网关ID)                        001631f8d7f2
#   网关品牌                                   ABLOOMY
#   医院名称                                 萧山区第二人民医院
#   医院级别                                        B级
#   status                                       1
#   报修日期                       2017-10-31 00:00:00
#   解决问题日期                     2017-10-31 00:00:00
#   报修问题        门诊3楼中医馆这里信号有，网络已经一个多星期不能使用了，希望尽快解决
#   解决方式                              外网停了，需自己开通宽带
#   解决人                                        黄开谛},
#  1311: {'Data':                ap_count        dhcp     portal   prelogin      login  \
#   title
#   troubleUvDay1         8         281        182         80         76
#   troubleUvDay2         9         283        202         85         84
#   troubleRate   -0.111111 -0.00706714 -0.0990099 -0.0588235 -0.0952381
#
#                 webforward hardforward forward_rate
#   title
#   troubleUvDay1         67          68     0.241993
#   troubleUvDay2         71          71     0.250883
#   troubleRate    -0.056338  -0.0422535   -0.0354368  ,
#   'Total':                     1311
#   hos_id              1311
#   故障类型                AP离线
#   AP型号             IAP-103
#   AP品牌               Aruba
#   GWID(网关ID)  001631f867e6
#   网关品牌             ABLOOMY
#   医院名称         东昌府区妇幼保健院分院
#   医院级别                  B级
#   status                 0
#   报修日期                 NaT
#   解决问题日期               NaT
#   报修问题                 NaN
#   解决方式                 NaN
#   解决人                  NaN},
#  1312: {'Data':                 ap_count       dhcp    portal  prelogin     login webforward  \
#   title
#   troubleUvDay1         26       1208       946       215       158        115
#   troubleUvDay2         28       1168       810       368       270        207
#   troubleRate   -0.0714286  0.0342466  0.167901 -0.415761 -0.414815  -0.444444
#
#                 hardforward forward_rate
#   title
#   troubleUvDay1         118    0.0976821
#   troubleUvDay2         209     0.178938
#   troubleRate     -0.435407    -0.454102  ,
#   'Total':                         1312
#   hos_id                  1312
#   故障类型              带宽负载较高（疑似）
#   AP型号                 IAP-103
#   AP品牌                   Aruba
#   GWID(网关ID)  61060300FF108D4C
#   网关品牌                      寰创
#   医院名称           铜仁市妇幼保健院（新院区）
#   医院级别                      B级
#   status                   NaN
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN}}
