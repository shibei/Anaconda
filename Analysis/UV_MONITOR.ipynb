# %%
import pymysql as psql
import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import datetime
import pymysql.cursors
from contextlib import contextmanager
import smtplib
import os
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email import encoders
from sqlalchemy import create_engine

# %%
#使用上下文管理器来连接数据库的函数
@contextmanager
def connect(server):
    database = pymysql.connect(**server)
    yield database 
    database.close()

#在数据库中执行命令函数
def sqlAction(database,action):
    with database.cursor() as cursor:
        # 执行sql语句，进行查询
        cursor.execute(action)
        # 获取查询结果
        result = cursor.fetchall()
    # 没有设置默认自动提交，需要主动提交，以保存所执行的语句
    database.commit()
    return result

class SqlServer(object):  # 定义sqlServer类，用来连接到mysql获取数据
    """docstring for sqlServer"""
    #   server的数据结构示例
    # {"server": { #数据库信息
    #     'host': 'localhost',#ip地址
    #     'port': 3066,端口号
    #     'user': 'root',用户名
    #     'password': 'password'密码,
    #     'db': 'db',数据库名称
    #     'charset': 'utf8mb4',编码方式
    #     'cursorclass': pymysql.cursors.DictCursor
    # },
    #     "comm": {命令描述和要执行的命令
    #     'apData': "SELECT * FROM `ap_count`",
    #     'uvData': "SELECT * FROM `funnel_model2`"
    # }}

    def __init__(self,server):
        self.server = server["server"]
        self.sqlComm = server["comm"]
    
#     只执行一条命令
    def getOneData(self,key):
        server = self.server
        with connect(server) as database:
            result = sqlAction(database,self.sqlComm[key])
#             print(result)
        try:
            df = pd.DataFrame(result)
        except:
            df =pd.DataFrame([])
        return df
    
#     执行所有命令
    def getAllData(self):
        server = self.server
        sqlDatas ={}
        with connect(server) as database:
            for key in self.sqlComm:
                result = pd.DataFrame(sqlAction(database,self.sqlComm[key]))
                sqlDatas[key] = result
        return sqlDatas

# 获取x天之前的日期
def getDate(x):
    today = datetime.date.today()
    oneday = datetime.timedelta(days=x)
    day = today-oneday
    return day

#重新排序列
def reColumns(df, columns=['hos_id','dhcp', 'portal', 
                           'prelogin', 'login', 'webforward', 
                           'hardforward', 'log_date']):
    for x in range(len(columns)):
        p = df.pop(columns[x])
        df.insert(x, columns[x], p)
    return df

def get400Data(day,cycle,path = r'/var/400data/400.xlsx'):
    day1 = getDate(day)
    day2 = getDate(day+cycle)
    data400 = pd.read_excel(path)
    data400.columns = data400.loc[0].values.tolist()
    data400 = data400.drop(0)
    data4001 = pd.DataFrame([])
    data4001[[r'报修日期', r'解决问题日期']] = data400[
        [r'报修日期', r'解决问题日期']].dropna().astype('datetime64[ns]')
    data4001[[r'医院名称', r'报修问题', r'解决方式', r'解决人']] = data400[
        [r'医院名称', r'报修问题', r'解决方式', r'解决人']]
    return data4001[(data4001[r'报修日期'] >= day2) & (data4001[r'报修日期'] <= day1)]

#从文件中获得DB信息
def getDbInfo(file,sheet):
    serverDf =np.transpose(pd.read_excel(file,sheet))
    serverCommList = {}
    for server in serverDf:
        serverComm = {"comm":{}}
        serverDict = serverDf[server].to_dict()
        serverDict['password'] = str(serverDict['password'])
        serverDict['charset'] = 'utf8mb4'
        serverDict['cursorclass'] = pymysql.cursors.DictCursor
        serverComm["server"] =serverDict
        serverCommList[server] = serverComm
    return serverCommList

#从文件中获得sender信息
def emailSender(file,sheet):
    senderDf = np.transpose(pd.read_excel(file,sheet))
    senderList = {}
    for sender in senderDf:
        senderDict = senderDf[sender].to_dict()
        senderList[sender] = senderDict
    return senderList

#从文件中获得receiver信息
def emailReceiver(file,sheet):
    receiveDf = pd.read_excel(file,sheet)
    return receiveDf['receive'].tolist()

# %%
def getRawData(day, cycle):

    day0 = str(getDate(0))
    day1 = str(getDate(day))
    day2 = str(getDate(day+cycle))
    dayX = '2017-09-26'

    DbList = getDbInfo(r'/root/ipython/user_list.xlsx',r'db_user')
    uvBase = DbList['uvBase']
    hosBase = DbList['hosBase']
    devBase = DbList['devBase']

    totalInfoFields = json.dumps(['HosID', 'Hospital', 'Value',
                                  'CurrentBroadbandBandwidth', 'GatewayVendor',
                                  'ApVendor', 'ApType', 'GWID']).strip('[').strip(']').replace('"', '')

    devInfoFields = json.dumps(['clock', 'cpuUsed', 'downSpeed',
                                'gwid', 'starttimeLong',
                                'status', 'wanIp']).strip('[').strip(']').replace('"', '')

    uvBase['comm']['apData'] = "SELECT * FROM `ap_count` WHERE \
    `log_date` = '%s' OR `log_date` = '%s' ORDER BY \
    `log_date` DESC" % (day2, day1)

    uvBase['comm']['uvData'] = "SELECT * FROM `funnel_model2` WHERE \
    `log_date` = '%s' OR `log_date` = '%s' ORDER BY \
    `log_date` DESC" % (day2, day1)

    devBase['comm']['devInfo'] = "SELECT %s FROM `dev_info` \
    WHERE `date` = '%s' ORDER BY `clock` DESC LIMIT 0, 1000" % (devInfoFields, dayX)

    hosBase['comm']['totalInfo'] = "SELECT %s FROM `TOTAL_INFO_T_%s`" % (
        totalInfoFields, day1.replace('-', ''))

    uvDatabase, hosDatabase, devDatabase = SqlServer(
        uvBase), SqlServer(hosBase), SqlServer(devBase)

    uvDataRaw, apDataRaw, hosInfoRaw, devInfoRaw = uvDatabase.getOneData('uvData'), uvDatabase.getOneData(
        'apData'), hosDatabase.getOneData('totalInfo'), devDatabase.getOneData('devInfo')

    data400Raw = get400Data(day, cycle)
    return uvDataRaw, apDataRaw,hosInfoRaw, devInfoRaw, data400Raw

# %%
# 清洗数据
def dataClean(uvData,apData):
    if len(uvData) > 0:
        reColumns(uvData)
        uvData = uvData.replace('\\N', 0).fillna(0).sort_values(
            by='log_date', ascending=False).reset_index(drop=True)
        uvDataGood = uvData[['hos_id','dhcp', 'portal', 'prelogin',
                             'login', 'webforward', 'hardforward']].astype('int32')
        uvDataGood['log_date'] = uvData['log_date'].astype('datetime64[ns]')
        uvDataGood['forward_rate'] = uvDataGood['hardforward']/uvDataGood['dhcp']
        uvDataLite = uvDataGood.drop(
            ['portal', 'prelogin', 'login', 'webforward'], axis=1)
    else:
        uvDataGood = uvData
        
    if len(apData) > 0:
        apData = apData.replace(['福建','安徽','福建省','安徽省',''],np.nan).dropna()
        apDataGood = apData[['hos_id','ap_count']].astype('int64')
        apDataGood['log_date'] = apData['log_date'].astype('datetime64[ns]')
    else:
        apDataGood = apData
    return uvDataGood,apDataGood

# %%
# 提取n天和n+r天前的数据
def getDateData(uvData, apData, day=1, cycle=7):
    d1 = day
    d2 = d1+cycle
    day1 = getDate(d1)
    day2 = getDate(d2)
    if len(uvData) >0:
        uvDay1 = uvData[uvData['log_date'] == day1].reset_index(
            drop=True).set_index('hos_id').drop('log_date', axis=1)
        uvDay2 = uvData[uvData['log_date'] == day2].reset_index(
            drop=True).set_index('hos_id').drop('log_date', axis=1)
    
    if len(apData) >0:
        apDay1 = apData[apData['log_date'] == day1].set_index(
            'hos_id').drop('log_date', axis=1)
        apDay2 = apData[apData['log_date'] == day2].set_index(
            'hos_id').drop('log_date', axis=1)
        uvDay1 = pd.merge(uvDay1, apDay1, left_index=True,
                          right_index=True, how='left')
        uvDay2 = pd.merge(uvDay2, apDay2, left_index=True,
                          right_index=True, how='left')
#     print(uvDay1.index, uvDay2.index)
    allHosid = np.union1d(uvDay1.index, uvDay2.index)
    uvDay1 = uvDay1.reindex(allHosid, fill_value=0)
    uvDay2 = uvDay2.reindex(allHosid, fill_value=0)
    
    if len(apData) >0:
        uvDay1.insert(0, 'ap_count', uvDay1.pop('ap_count'))
        uvDay2.insert(0, 'ap_count', uvDay2.pop('ap_count'))
    
    uvDay2Lite = uvDay2[uvDay2['dhcp'] > 200]
    uvDay1Lite = uvDay1.reindex(uvDay2Lite.index)
    return uvDay1, uvDay2, uvDay1Lite, uvDay2Lite

# %%
#依靠经验值来构建的决策树

def decisionTree(data,rawData,apLimit = -0.1,forwardLimit = -0.4 ,globalLimit = -0.4):
    index = data.index #获得目录
    splitTerm0 = data[index[0]] <= globalLimit #分裂条件0
    if len(index) > 1:
        splitTerm1 = data[index[1]] <= 0.5*globalLimit #分裂条件1
    
    #"""决策树第一层"""
    #如果data的第一行索引名为'ap_count',并且第一行值等于-1，那么返回‘网关离线’。（AP全掉了）
    if index[0] == 'ap_count' and data[index[0]] == -1:
        return '网关离线' 
    
    #如果data的第一行索引名为'ap_count',并且第一行值小于apLimi同时不等于-1，那么返回‘AP离线’。（AP掉了一部分）
    elif index[0] == 'ap_count' and data[index[0]] <= apLimit and data[index[0]] != -1:
        return 'AP离线'
    
    #如果data的第一行索引名为'ap_count',并且第一行值大于apLimit，那么data去除第一行，其他参数保持不变，进行递归
    #（如果AP数量没有下降，那么进行下一步判断）
    elif index[0] == 'ap_count' and data[index[0]] > apLimit:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第二层"""
    #如果data的第一行索引名为'dhcp',并且同时满足分裂条件0和1，那么返回'未知'。（莫名其妙的DHCP数就下降了）
    elif index[0] == 'dhcp' and splitTerm0 and splitTerm1:
        return '未知  '+index[0]+'<'+str(globalLimit)
    
    #如果data的第一行索引名为'dhcp',并且满足分裂条件0,不满足分裂条件1，那么返回'DHCP统计错误'。（只有DHCP数下降了）
    elif index[0] == 'dhcp' and splitTerm0 and not splitTerm1:
        return 'DHCP统计错误'
    
    #如果data的第一行索引名为'dhcp',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果DHCP数没有下降，那么进行下一步判断）
    elif index[0] == 'dhcp' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第三层"""
    #如果data的第一行索引名为'portal',并且同时满足分裂条件0和1，那么返回'重定向故障'。（莫名其妙的portal数就下降了）
    elif index[0] == 'portal' and splitTerm0 and splitTerm1:
        return '重定向故障'
    
    #如果data的第一行索引名为'portal',并且满足分裂条件0不满足分裂条件1，那么返回'portal打点故障'。（只有portal数下降了）
    elif index[0] == 'portal' and splitTerm0 and not splitTerm1:
        return 'portal打点故障'
    
    #如果data的第一行索引名为'portal',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果portal数没有下降，那么进行下一步判断）
    elif index[0] == 'portal' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    
    
    #"""决策树第四层"""
    #如果data的第一行索引名为'prelogin',并且同时满足分裂条件0和1，那么返回'带宽负载较高（疑似）'。（预登陆人数变少了，可能是带宽造成的）
    elif index[0] == 'prelogin' and splitTerm0 and splitTerm1:
        return '带宽负载较高（疑似）'
    
    #如果data的第一行索引名为'prelogin',并且满足分裂条件0不满足分裂条件1，那么返回'prelogin打点故障'。（只有prelogin数下降了）
    elif index[0] == 'prelogin' and splitTerm0 and not splitTerm1:
        return 'prelogin打点故障'
    
    #如果data的第一行索引名为'prelogin',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果prelogin数没有下降，那么进行下一步判断）
    elif index[0] == 'prelogin' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)
    

    #"""决策树第五层"""
    #如果data的第一行索引名为'login',并且同时满足分裂条件0和1，那么返回'未知'。（莫名其妙的login数就变少了）
    elif index[0] == 'login' and splitTerm0 and splitTerm1:
        return '未知'+index[0]+'<'+str(globalLimit)
    
    #如果data的第一行索引名为'login',并且满足分裂条件0不满足分裂条件1，那么返回'login打点故障'。（只有login数下降了）
    elif index[0] == 'login' and splitTerm0 and not splitTerm1:
        return 'login打点故障'
    
    #如果data的第一行索引名为'login',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果login数没有下降，那么进行下一步判断）
    elif index[0] == 'login' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第六层"""
    #如果data的第一行索引名为'webforward',并且同时满足分裂条件0和1，那么返回'web放行故障'。（莫名其妙的webforward数就变少了）
    elif index[0] == 'webforward' and splitTerm0 and splitTerm1:
        return 'web放行故障'
    
    #如果data的第一行索引名为'webforward',并且满足分裂条件0不满足分裂条件1，那么返回'webforward打点故障'。（只有webforward数下降了）
    elif index[0] == 'webforward' and splitTerm0 and not splitTerm1:
        return 'webforward打点故障'
    
    #如果data的第一行索引名为'webforward',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果webforward数没有下降，那么进行下一步判断）
    elif index[0] == 'webforward' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第七层"""
    #如果data的第一行索引名为'hardforward',并且满足分裂条件0，那么返回'硬件放行故障'。（莫名其妙的hardforward数就变少了）
    elif index[0] == 'hardforward' and splitTerm0:
        return '硬件放行故障'
    
    #如果data的第一行索引名为'hardforward',并且不满足分裂条件0，那么data去除第一行，其他参数保持不变，进行递归
    #（如果hardforward数没有下降，那么进行下一步判断）
    elif index[0] == 'hardforward' and not splitTerm0:
        return decisionTree(data[1:],rawData,apLimit,forwardLimit,globalLimit)


    #"""决策树第八层"""
    #如果data的第一行索引名为'forward_rate',并且不满足分裂条件0，那么返回'正常'。（正常情况）
    elif index[0] == 'forward_rate' and not splitTerm0:
        return '正常'
    
    #如果data的第一行索引名为'forward_rate',并且满足分裂条件0，那么赋值rawData到data，globalLimit - 0.05,其他参数保持不变，进行递归
    #（如果其他参数正常，只有forward_rate变少了，那么减小分裂系数，重新进行分析，）
    elif index[0] == 'forward_rate' and not splitTerm0:
        return decisionTree(rawData,rawData,apLimit,forwardLimit,globalLimit-0.05)

# %%
def analysis(day,cycle,apLimit = -0.1,forwardLimit = -0.4 ,globalLimit = -0.4):
    uvDataRaw, apDataRaw,hosInfoRaw, devInfoRaw, data400Raw = getRawData(day, cycle)
    uvDataGood,apDataGood = dataClean(uvDataRaw,apDataRaw)
    uvDay1, uvDay2, uvDay1Lite,uvDay2Lite = getDateData(uvDataGood,apDataGood,day,cycle)
    rate =((uvDay1Lite.reindex(uvDay2Lite.index).fillna(0)-uvDay2Lite)/uvDay2Lite)
    troubleList = {}
    for hos in rate.index:
        trouble = decisionTree(rate.loc[hos],rate.loc[hos],-0.1,-0.4,-0.4)
        troubleList[hos] = trouble
    statusSeries = pd.Series(troubleList)
    troubleHos = statusSeries[statusSeries !='正常']
    troubleDf = pd.DataFrame(troubleHos,columns=['故障类型'])
    troubleDf.insert(0,'hos_id',troubleDf.index)
    troubleRate =pd.merge(troubleDf,rate,left_on='hos_id',right_index=True)
    troubleUvDay1=pd.merge(troubleDf,uvDay1,left_on='hos_id',right_index=True)
    troubleUvDay2 =pd.merge(troubleDf,uvDay2,left_on='hos_id',right_index=True)
    troubleTotal = mergeDf(troubleDf,hosInfoRaw, devInfoRaw, data400Raw)[[
        'hos_id',r'故障类型',r'AP型号',r'AP品牌',r'GWID(网关ID)','网关品牌',
        '医院名称','医院级别','status','报修日期','解决问题日期','报修问题',
        '解决方式','解决人']]
    troubleTotal[['报修日期','解决问题日期']].astype('datetime64[ns]')
    if 0 in troubleTotal['hos_id']:troubleTotal = troubleTotal.drop(0)
    troubleTotal = troubleTotal.set_index('hos_id',drop = False)
    troubleInfo = {
        'troubleTotal':troubleTotal,
        'troubleRate':troubleRate,
        'troubleUvDay1' :troubleUvDay1,
        'troubleUvDay2' : troubleUvDay2
    }
    return troubleInfo

# %%
def mergeDf(troubleDf,hosInfoRaw, devInfoRaw, data400Raw):
    hosInfoRaw.columns = hosInfoRaw.loc[0]
    hosInfoRaw = hosInfoRaw.set_index('HosID')
    hosInfoRaw = hosInfoRaw.reindex(hosInfoRaw.index.dropna()).drop('HosID')
    hosInfoRaw.index = hosInfoRaw.index.astype('int32')
    devInfo = devInfoRaw[devInfoRaw['clock'] == devInfoRaw['clock'].loc[0]]
    troubleDfTotal = pd.merge(troubleDf,hosInfoRaw,left_on='hos_id',right_index=True,how='left')
    troubleDfTotal = pd.merge(troubleDfTotal,devInfo,left_on=r'GWID(网关ID)',right_on='gwid',how='left')
    troubleDfTotal = pd.merge(troubleDfTotal,data400Raw,left_on=r'医院名称',right_on='医院名称',how='left')
    return troubleDfTotal

# %%
def chineseNumber(x):
    num=['零','一','二','三','四','五','六','七','八','九']  
    return num[x]

def englishNumber(x):
    num=['ZERO','ONE','TWO','THREE','FOUR','FIVE','SIX','SEVEN','EIGHT','NINE','TEN']  
    return num[x]

# %%
def sendEmail(pathList,day,cycle):
    senderList = emailSender(r'/root/ipython/user_list.xlsx',r'email_sender')
    receiverList = emailReceiver(r'/root/ipython/user_list.xlsx',r'email_receive')
    user = senderList['qq']['user']
    pwd = senderList['qq']['password']
    to = ','.join(receiverList)
    msg = MIMEMultipart()
    title =  '%s周对比分析_%s' % (chineseNumber(cycle),str(getDate(day)))
    message =  '附件为%s的%s周对比分析结果' %  (str(getDate(day)),chineseNumber(cycle))
    msg['Subject'] = title
#     msg['From'] = r'UV_MONITOR'
    content1 = MIMEText(message, 'plain', 'utf-8')
    msg.attach(content1)
    for path in pathList:
        attfile = path
        basename = os.path.basename(attfile)
        fp = open(attfile, 'rb')
        att = MIMEText(fp.read(), 'base64', 'utf-8')
        att["Content-Type"] = 'application/octet-stream'
        att.add_header('Content-Disposition', 'attachment',filename=('gbk', '', basename))
        encoders.encode_base64(att)
        msg.attach(att)
    #-----------------------------------------------------------
    s = smtplib.SMTP('smtp.qq.com')
    s.login(user, pwd)
    s.sendmail(user, to, msg.as_string())
    s.close()

def MySql(troubleInfo,day=1,cycle=1):
    outPutServer = getDbInfo(r'/root/ipython/user_list.xlsx',r'db_user')['devBase']['server']
    engine = create_engine('mysql+pymysql://%s:%s@%s:%d/%s'%(outPutServer['user'],
                                                             outPutServer['password'],
                                                             outPutServer['host'],
                                                             outPutServer['port'],
                                                             outPutServer['db']),connect_args={'charset':'utf8'})
    for trouble in troubleInfo:
        troubleInfo[trouble]['date'] = getDate(day)
        troubleInfo[trouble].to_sql(name='%d_TROUBLE_%s_ON_%s_WEEK'%(cycle,str.upper(trouble[7:]),
                                                              englishNumber(cycle)),
                                con=engine,if_exists='append',index=False)

# %%
def output(day=1, cycle=1,toEmail = True,toSql=True):
    Path = r'/root/ipython/UV分析结果/%s周对比/%s周对比_%s.xlsx' % (chineseNumber(cycle),chineseNumber(cycle), str(getDate(day)))
    day2 = cycle*7
    writer = pd.ExcelWriter(Path)
    troubleInfo= analysis(day, day2)
    pathList = []
    for x in troubleInfo:
        troubleInfo[x].to_excel(writer,x)
        pathList.append(Path)
    writer.save()
    if toEmail:
        sendEmail(pathList,day,cycle)
    if toSql:
        toMySql(troubleInfo,day,cycle)

# %%
def main():
    output(1,1)
    output(1,4,toEmail=False)

# %%
if __name__ == '__main__':
    main()

# %%
def reconfigOut():
    t = analysis(1,1*7)
    out = {}
    for id in t['troubleTotal']['hos_id']:
        out1 = {}
        hosName = 
        for x in t:
            u=t[x]
            o  = u[u['hos_id']== id]
            if x != 'troubleTotal':
                o = u.loc[id][2:]
            else:
                o = u.loc[id]
            out1[x] = o
        out[id]=out1
    return out

# %%
o1 = reconfigOut()

# %%
o1[57]
# Out:
# {'troubleRate': ap_count             -0.1
#  dhcp            0.0780822
#  portal          0.0971338
#  prelogin         0.103448
#  login           0.0920635
#  webforward       0.043771
#  hardforward      0.114983
#  forward_rate    0.0342278
#  Name: 57, dtype: object, 'troubleTotal': hos_id                  57
#  故障类型                  AP离线
#  AP型号                  R300
#  AP品牌                Ruckus
#  GWID(网关ID)    001631f9874e
#  网关品牌               ABLOOMY
#  医院名称              承德市妇幼保健院
#  医院级别                    B级
#  status                   1
#  报修日期                   NaT
#  解决问题日期                 NaT
#  报修问题                   NaN
#  解决方式                   NaN
#  解决人                    NaN
#  Name: 57, dtype: object, 'troubleUvDay1': ap_count               9
#  dhcp                 787
#  portal               689
#  prelogin             352
#  login                344
#  webforward           310
#  hardforward          320
#  forward_rate    0.406607
#  Name: 57, dtype: object, 'troubleUvDay2': ap_count              10
#  dhcp                 730
#  portal               628
#  prelogin             319
#  login                315
#  webforward           297
#  hardforward          287
#  forward_rate    0.393151
#  Name: 57, dtype: object}

# %%
t = analysis(1,1*7)

# %%
t['troubleTotal'].loc[62]
# Out:
# hos_id                  62
# 故障类型                  AP离线
# AP型号               IAP-103
# AP品牌                 Aruba
# GWID(网关ID)    001631f1b96c
# 网关品牌           ABLOOMY-中苗刷
# 医院名称              文安县妇幼保健院
# 医院级别                    F级
# status                   0
# 报修日期                   NaT
# 解决问题日期                 NaT
# 报修问题                   NaN
# 解决方式                   NaN
# 解决人                    NaN
# Name: 62, dtype: object

# %%
t['troubleTotal']['hos_id']
# Out:
# hos_id
# 57        57
# 62        62
# 134      134
# 141      141
# 186      186
# 188      188
# 192      192
# 195      195
# 204      204
# 204      204
# 210      210
# 297      297
# 449      449
# 457      457
# 568      568
# 630      630
# 636      636
# 679      679
# 692      692
# 720      720
# 755      755
# 815      815
# 817      817
# 853      853
# 954      954
# 969      969
# 969      969
# 969      969
# 1052    1052
# 1072    1072
# 1116    1116
# 1117    1117
# 1304    1304
# Name: hos_id, dtype: int64

# %%
out = {}
for id in t['troubleTotal']['hos_id']:
#     print(id)
    out1 = {}
    hosName = t['troubleTotal'].loc[id]
#     print(hosName)
    for x in t:
        u=t[x]
        print(x)
#         o  = u[u['hos_id']== id]
#         if x != 'troubleTotal':
#             o = u.loc[id][2:]
#         else:
#             o = u.loc[id]
#         out1[x] = o
#     out[hosName]=out1
# Out:
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2
# troubleTotal
# troubleRate
# troubleUvDay1
# troubleUvDay2

# %%
out
# Out:
# {'伊犁哈萨克自治州妇幼保健院': {'troubleRate': ap_count              -0.1
#   dhcp            -0.0166667
#   portal          0.00328587
#   prelogin         0.0230263
#   login                    0
#   webforward       -0.011236
#   hardforward     -0.0688935
#   forward_rate    -0.0531121
#   Name: 679, dtype: object, 'troubleTotal': hos_id                     679
#   故障类型                      AP离线
#   AP型号                      R300
#   AP品牌                    Ruckus
#   GWID(网关ID)    61060300FF107642
#   网关品牌                        寰创
#   医院名称             伊犁哈萨克自治州妇幼保健院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 679, dtype: object, 'troubleUvDay1': ap_count               9
#   dhcp                1003
#   portal               916
#   prelogin             622
#   login                524
#   webforward           440
#   hardforward          446
#   forward_rate    0.444666
#   Name: 679, dtype: object, 'troubleUvDay2': ap_count              10
#   dhcp                1020
#   portal               913
#   prelogin             608
#   login                524
#   webforward           445
#   hardforward          479
#   forward_rate    0.469608
#   Name: 679, dtype: object}, '公主岭市妇幼保健院': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 204, dtype: object, 'troubleTotal': hos_id                 204
#   故障类型                  网关离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f1b98c
#   网关品牌               ABLOOMY
#   医院名称             公主岭市妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 204, dtype: object, 'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 204, dtype: object, 'troubleUvDay2': ap_count               8
#   dhcp                 609
#   portal               520
#   prelogin             239
#   login                229
#   webforward           206
#   hardforward          208
#   forward_rate    0.341544
#   Name: 204, dtype: object}, '兰考县妇幼保健院（新院区）': {'troubleRate': ap_count        -0.166667
#   dhcp            0.0242291
#   portal         -0.0162413
#   prelogin       -0.0521472
#   login          -0.0749601
#   webforward     -0.0949033
#   hardforward     -0.112628
#   forward_rate     -0.13362
#   Name: 141, dtype: object,
#   'troubleTotal': hos_id                     141
#   故障类型                      AP离线
#   AP型号                    N200-单
#   AP品牌                        寰创
#   GWID(网关ID)    61060300FF109292
#   网关品牌                        寰创
#   医院名称             兰考县妇幼保健院（新院区）
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 141, dtype: object,
#   'troubleUvDay1': ap_count              5
#   dhcp                930
#   portal              848
#   prelogin            618
#   login               580
#   webforward          515
#   hardforward         520
#   forward_rate    0.55914
#   Name: 141, dtype: object,
#   'troubleUvDay2': ap_count               6
#   dhcp                 908
#   portal               862
#   prelogin             652
#   login                627
#   webforward           569
#   hardforward          586
#   forward_rate    0.645374
#   Name: 141, dtype: object}, '内江市妇幼保健院': {'troubleRate': ap_count                0
#   dhcp            0.0491803
#   portal          0.0677083
#   prelogin         0.173077
#   login                0.22
#   webforward           -0.5
#   hardforward      0.333333
#   forward_rate     0.270833
#   Name: 192, dtype: object,
#   'troubleTotal': hos_id                     192
#   故障类型            webforward打点故障
#   AP型号                   IAP-103
#   AP品牌                     Aruba
#   GWID(网关ID)    0a70eddb3cF006AC
#   网关品牌                    寰创-中苗刷
#   医院名称                  内江市妇幼保健院
#   医院级别                        F级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 192, dtype: object,
#   'troubleUvDay1': ap_count           9
#   dhcp             320
#   portal           205
#   prelogin          61
#   login             61
#   webforward         1
#   hardforward       48
#   forward_rate    0.15
#   Name: 192, dtype: object,
#   'troubleUvDay2': ap_count               9
#   dhcp                 305
#   portal               192
#   prelogin              52
#   login                 50
#   webforward             2
#   hardforward           36
#   forward_rate    0.118033
#   Name: 192, dtype: object}, '南岳区妇幼保健院': {'troubleRate': ap_count             -0.1
#   dhcp            0.0171674
#   portal          0.0244648
#   prelogin        0.0778443
#   login               0.168
#   webforward      0.0818182
#   hardforward     0.0603448
#   forward_rate    0.0424487
#   Name: 134, dtype: object,
#   'troubleTotal': hos_id                     134
#   故障类型                      AP离线
#   AP型号                      N200
#   AP品牌                        寰创
#   GWID(网关ID)    61060300FF0C1202
#   网关品牌                        寰创
#   医院名称                  南岳区妇幼保健院
#   医院级别                      收费医院
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 134, dtype: object,
#   'troubleUvDay1': ap_count               9
#   dhcp                 474
#   portal               335
#   prelogin             180
#   login                146
#   webforward           119
#   hardforward          123
#   forward_rate    0.259494
#   Name: 134, dtype: object,
#   'troubleUvDay2': ap_count              10
#   dhcp                 466
#   portal               327
#   prelogin             167
#   login                125
#   webforward           110
#   hardforward          116
#   forward_rate    0.248927
#   Name: 134, dtype: object}, '吉林市龙潭区妇幼保健院': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 692, dtype: object, 'troubleTotal': hos_id                 692
#   故障类型                  网关离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f1b7cc
#   网关品牌               ABLOOMY
#   医院名称           吉林市龙潭区妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 692, dtype: object, 'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 692, dtype: object, 'troubleUvDay2': ap_count              14
#   dhcp                 581
#   portal               509
#   prelogin             263
#   login                255
#   webforward           232
#   hardforward          235
#   forward_rate    0.404475
#   Name: 692, dtype: object}, '富阳市第二人民医院（富阳区第二人民医院）': {'troubleRate': ap_count       -0.027027
#   dhcp           -0.865462
#   portal         -0.887255
#   prelogin       -0.929648
#   login          -0.925926
#   webforward     -0.927273
#   hardforward    -0.931034
#   forward_rate   -0.487391
#   Name: 815, dtype: object,
#   'troubleTotal': hos_id                         815
#   故障类型                 未知  dhcp<-0.4
#   AP型号                       IAP-103
#   AP品牌                         Aruba
#   GWID(网关ID)            001631f1b740
#   网关品牌                       ABLOOMY
#   医院名称          富阳市第二人民医院（富阳区第二人民医院）
#   医院级别                            F级
#   status                           1
#   报修日期                           NaT
#   解决问题日期                         NaT
#   报修问题                           NaN
#   解决方式                           NaN
#   解决人                            NaN
#   Name: 815, dtype: object,
#   'troubleUvDay1': ap_count              36
#   dhcp                  67
#   portal                46
#   prelogin              14
#   login                 14
#   webforward            12
#   hardforward           12
#   forward_rate    0.179104
#   Name: 815, dtype: object,
#   'troubleUvDay2': ap_count              37
#   dhcp                 498
#   portal               408
#   prelogin             199
#   login                189
#   webforward           165
#   hardforward          174
#   forward_rate    0.349398
#   Name: 815, dtype: object}, '射阳县中医院': {'troubleRate': ap_count       -0.0454545
#   dhcp             0.126238
#   portal           -0.57971
#   prelogin         0.124183
#   login            0.112583
#   webforward      0.0652174
#   hardforward     0.0857143
#   forward_rate   -0.0359812
#   Name: 1052, dtype: object,
#   'troubleTotal': hos_id                1052
#   故障类型            portal打点故障
#   AP型号               IAP-103
#   AP品牌                 Aruba
#   GWID(网关ID)    001631f1b418
#   网关品牌               ABLOOMY
#   医院名称                射阳县中医院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 1052, dtype: object,
#   'troubleUvDay1': ap_count              21
#   dhcp                 455
#   portal               145
#   prelogin             172
#   login                168
#   webforward           147
#   hardforward          152
#   forward_rate    0.334066
#   Name: 1052, dtype: object,
#   'troubleUvDay2': ap_count              22
#   dhcp                 404
#   portal               345
#   prelogin             153
#   login                151
#   webforward           138
#   hardforward          140
#   forward_rate    0.346535
#   Name: 1052, dtype: object}, '广饶县妇幼保健院（广饶县妇女儿童医院）': {'troubleRate': ap_count         -0.666667
#   dhcp            0.00405844
#   portal           0.0257353
#   prelogin         0.0151899
#   login            0.0274964
#   webforward        0.084507
#   hardforward     0.00831947
#   forward_rate     0.0042438
#   Name: 755, dtype: object,
#   'troubleTotal': hos_id                        755
#   故障类型                         AP离线
#   AP型号                         N200
#   AP品牌                           寰创
#   GWID(网关ID)       61060300FF0C2EEA
#   网关品牌                           寰创
#   医院名称          广饶县妇幼保健院（广饶县妇女儿童医院）
#   医院级别                         DEAD
#   status                        NaN
#   报修日期                          NaT
#   解决问题日期                        NaT
#   报修问题                          NaN
#   解决方式                          NaN
#   解决人                           NaN
#   Name: 755, dtype: object,
#   'troubleUvDay1': ap_count               3
#   dhcp                1237
#   portal              1116
#   prelogin             802
#   login                710
#   webforward           154
#   hardforward          606
#   forward_rate    0.489895
#   Name: 755, dtype: object,
#   'troubleUvDay2': ap_count               9
#   dhcp                1232
#   portal              1088
#   prelogin             790
#   login                691
#   webforward           142
#   hardforward          601
#   forward_rate    0.487825
#   Name: 755, dtype: object}, '庐江县人民医院': {'troubleRate': ap_count                0
#   dhcp            0.0378469
#   portal          0.0222618
#   prelogin        0.0179211
#   login            0.012963
#   webforward      -0.893333
#   hardforward    -0.0208333
#   forward_rate   -0.0565404
#   Name: 636, dtype: object,
#   'troubleTotal': hos_id                   636
#   故障类型          webforward打点故障
#   AP型号                    R300
#   AP品牌                  Ruckus
#   GWID(网关ID)      001631f1ba5c
#   网关品牌                 ABLOOMY
#   医院名称                 庐江县人民医院
#   医院级别                      B级
#   status                     1
#   报修日期                     NaT
#   解决问题日期                   NaT
#   报修问题                     NaN
#   解决方式                     NaN
#   解决人                      NaN
#   Name: 636, dtype: object,
#   'troubleUvDay1': ap_count              17
#   dhcp                1234
#   portal              1148
#   prelogin             568
#   login                547
#   webforward            40
#   hardforward          470
#   forward_rate    0.380875
#   Name: 636, dtype: object,
#   'troubleUvDay2': ap_count              17
#   dhcp                1189
#   portal              1123
#   prelogin             558
#   login                540
#   webforward           375
#   hardforward          480
#   forward_rate    0.403701
#   Name: 636, dtype: object}, '户县妇幼保健院': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 186, dtype: object, 'troubleTotal': hos_id                 186
#   故障类型                  网关离线
#   AP型号               IAP-103
#   AP品牌                 Aruba
#   GWID(网关ID)    001631f98a16
#   网关品牌               ABLOOMY
#   医院名称               户县妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 186, dtype: object, 'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 186, dtype: object, 'troubleUvDay2': ap_count              24
#   dhcp                 795
#   portal               717
#   prelogin             891
#   login                878
#   webforward           483
#   hardforward          327
#   forward_rate    0.411321
#   Name: 186, dtype: object}, '承德市妇幼保健院': {'troubleRate': ap_count             -0.1
#   dhcp            0.0780822
#   portal          0.0971338
#   prelogin         0.103448
#   login           0.0920635
#   webforward       0.043771
#   hardforward      0.114983
#   forward_rate    0.0342278
#   Name: 57, dtype: object,
#   'troubleTotal': hos_id                  57
#   故障类型                  AP离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f9874e
#   网关品牌               ABLOOMY
#   医院名称              承德市妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 57, dtype: object,
#   'troubleUvDay1': ap_count               9
#   dhcp                 787
#   portal               689
#   prelogin             352
#   login                344
#   webforward           310
#   hardforward          320
#   forward_rate    0.406607
#   Name: 57, dtype: object,
#   'troubleUvDay2': ap_count              10
#   dhcp                 730
#   portal               628
#   prelogin             319
#   login                315
#   webforward           297
#   hardforward          287
#   forward_rate    0.393151
#   Name: 57, dtype: object}, '文安县妇幼保健院': {'troubleRate': ap_count        -0.333333
#   dhcp              0.15873
#   portal          0.0863636
#   prelogin        -0.136364
#   login          -0.0952381
#   webforward              0
#   hardforward     -0.176471
#   forward_rate    -0.289283
#   Name: 62, dtype: object,
#   'troubleTotal': hos_id                  62
#   故障类型                  AP离线
#   AP型号               IAP-103
#   AP品牌                 Aruba
#   GWID(网关ID)    001631f1b96c
#   网关品牌           ABLOOMY-中苗刷
#   医院名称              文安县妇幼保健院
#   医院级别                    F级
#   status                   0
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 62, dtype: object,
#   'troubleUvDay1': ap_count                2
#   dhcp                  292
#   portal                239
#   prelogin               38
#   login                  38
#   webforward              7
#   hardforward            28
#   forward_rate    0.0958904
#   Name: 62, dtype: object,
#   'troubleUvDay2': ap_count               3
#   dhcp                 252
#   portal               220
#   prelogin              44
#   login                 42
#   webforward             7
#   hardforward           34
#   forward_rate    0.134921
#   Name: 62, dtype: object}, '新昌县人民医院': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 1117, dtype: object, 'troubleTotal': hos_id                    1117
#   故障类型                      网关离线
#   AP型号                      N200
#   AP品牌                        寰创
#   GWID(网关ID)    b3d5c3c7f50D472F
#   网关品牌                        寰创
#   医院名称                   新昌县人民医院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 1117, dtype: object, 'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 1117, dtype: object, 'troubleUvDay2': ap_count              75
#   dhcp                 894
#   portal               580
#   prelogin             374
#   login                330
#   webforward           280
#   hardforward          283
#   forward_rate    0.316555
#   Name: 1117, dtype: object}, '新昌县妇女儿童医院（新昌县人民医院城东分院）': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 1116, dtype: object,
#   'troubleTotal': hos_id                          1116
#   故障类型                            网关离线
#   AP型号                         IAP-103
#   AP品牌                           Aruba
#   GWID(网关ID)          61060300FF0C9556
#   网关品牌                              寰创
#   医院名称          新昌县妇女儿童医院（新昌县人民医院城东分院）
#   医院级别                              B级
#   status                           NaN
#   报修日期                             NaT
#   解决问题日期                           NaT
#   报修问题                             NaN
#   解决方式                             NaN
#   解决人                              NaN
#   Name: 1116, dtype: object,
#   'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 1116, dtype: object,
#   'troubleUvDay2': ap_count              59
#   dhcp                 838
#   portal               686
#   prelogin             456
#   login                427
#   webforward           359
#   hardforward          384
#   forward_rate    0.458234
#   Name: 1116, dtype: object}, '晋中市妇幼保健院': {'troubleRate': ap_count             -0.25
#   dhcp            -0.0114374
#   portal          -0.0517806
#   prelogin        -0.0481343
#   login           -0.0490916
#   webforward         10.2708
#   hardforward     0.00362319
#   forward_rate     0.0152348
#   Name: 457, dtype: object,
#   'troubleTotal': hos_id                 457
#   故障类型                  AP离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    00900b404b70
#   网关品牌               ABLOOMY
#   医院名称              晋中市妇幼保健院
#   医院级别                    F级
#   status                 NaN
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 457, dtype: object,
#   'troubleUvDay1': ap_count               3
#   dhcp                6396
#   portal              4633
#   prelogin            2551
#   login               2460
#   webforward          2164
#   hardforward         2216
#   forward_rate    0.346467
#   Name: 457, dtype: object,
#   'troubleUvDay2': ap_count               4
#   dhcp                6470
#   portal              4886
#   prelogin            2680
#   login               2587
#   webforward           192
#   hardforward         2208
#   forward_rate    0.341267
#   Name: 457, dtype: object}, '杭州市红十字会医院': {'troubleRate': ap_count               0
#   dhcp           -0.681183
#   portal         -0.706167
#   prelogin       -0.714539
#   login          -0.696078
#   webforward     -0.716332
#   hardforward    -0.717033
#   forward_rate   -0.112446
#   Name: 210, dtype: object,
#   'troubleTotal': hos_id                     210
#   故障类型             未知  dhcp<-0.4
#   AP型号                      N200
#   AP品牌                        寰创
#   GWID(网关ID)    61060300FF0CBD6A
#   网关品牌                        寰创
#   医院名称                 杭州市红十字会医院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 210, dtype: object,
#   'troubleUvDay1': ap_count              40
#   dhcp                 388
#   portal               243
#   prelogin             161
#   login                124
#   webforward            99
#   hardforward          103
#   forward_rate    0.265464
#   Name: 210, dtype: object,
#   'troubleUvDay2': ap_count              40
#   dhcp                1217
#   portal               827
#   prelogin             564
#   login                408
#   webforward           349
#   hardforward          364
#   forward_rate    0.299096
#   Name: 210, dtype: object}, '桂林市中医医院铁西分院': {'troubleRate': ap_count           -0.125
#   dhcp            0.0737463
#   portal          0.0647359
#   prelogin         0.208092
#   login            0.205882
#   webforward       0.111111
#   hardforward      0.153846
#   forward_rate    0.0745985
#   Name: 720, dtype: object,
#   'troubleTotal': hos_id                 720
#   故障类型                  AP离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f98a22
#   网关品牌               ABLOOMY
#   医院名称           桂林市中医医院铁西分院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 720, dtype: object,
#   'troubleUvDay1': ap_count               7
#   dhcp                 728
#   portal               625
#   prelogin             209
#   login                205
#   webforward            30
#   hardforward          165
#   forward_rate    0.226648
#   Name: 720, dtype: object,
#   'troubleUvDay2': ap_count               8
#   dhcp                 678
#   portal               587
#   prelogin             173
#   login                170
#   webforward            27
#   hardforward          143
#   forward_rate    0.210914
#   Name: 720, dtype: object}, '梧州市工人医院': {'troubleRate': ap_count                0
#   dhcp           -0.0106838
#   portal          -0.997319
#   prelogin        -0.157895
#   login           -0.136054
#   webforward      -0.145038
#   hardforward           NaN
#   forward_rate          NaN
#   Name: 297, dtype: object,
#   'troubleTotal': hos_id                 297
#   故障类型            portal打点故障
#   AP型号               IAP-103
#   AP品牌                 Aruba
#   GWID(网关ID)    001631f8672a
#   网关品牌               ABLOOMY
#   医院名称               梧州市工人医院
#   医院级别                    F级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 297, dtype: object,
#   'troubleUvDay1': ap_count          8
#   dhcp            463
#   portal            1
#   prelogin        128
#   login           127
#   webforward      112
#   hardforward       0
#   forward_rate      0
#   Name: 297, dtype: object,
#   'troubleUvDay2': ap_count          8
#   dhcp            468
#   portal          373
#   prelogin        152
#   login           147
#   webforward      131
#   hardforward       0
#   forward_rate      0
#   Name: 297, dtype: object}, '江西省都昌县人民医院': {'troubleRate': ap_count                0
#   dhcp            0.0331633
#   portal          0.0295567
#   prelogin        -0.553541
#   login           -0.545195
#   webforward      -0.453988
#   hardforward      0.141509
#   forward_rate     0.104868
#   Name: 969, dtype: object,
#   'troubleTotal': hos_id                    969
#   故障类型               带宽负载较高（疑似）
#   AP型号                     R300
#   AP品牌                Ruckus+寰创
#   GWID(网关ID)    61060300FF0C93C
#   网关品牌                       寰创
#   医院名称               江西省都昌县人民医院
#   医院级别                       B级
#   status                    NaN
#   报修日期                      NaT
#   解决问题日期                    NaT
#   报修问题                      NaN
#   解决方式                      NaN
#   解决人                       NaN
#   Name: 969, dtype: object,
#   'troubleUvDay1': ap_count              30
#   dhcp                 405
#   portal               418
#   prelogin             517
#   login                478
#   webforward            89
#   hardforward          121
#   forward_rate    0.298765
#   Name: 969, dtype: object,
#   'troubleUvDay2': ap_count              30
#   dhcp                 392
#   portal               406
#   prelogin            1158
#   login               1051
#   webforward           163
#   hardforward          106
#   forward_rate    0.270408
#   Name: 969, dtype: object}, '济宁市妇幼保健院': {'troubleRate': ap_count                0
#   dhcp            -0.507407
#   portal          -0.479016
#   prelogin        -0.470437
#   login           -0.468586
#   webforward      -0.491379
#   hardforward     -0.497253
#   forward_rate    0.0206147
#   Name: 449, dtype: object,
#   'troubleTotal': hos_id                  449
#   故障类型          未知  dhcp<-0.4
#   AP型号                IAP-103
#   AP品牌                  Aruba
#   GWID(网关ID)     001631f8d7e2
#   网关品牌                ABLOOMY
#   医院名称               济宁市妇幼保健院
#   医院级别                     B级
#   status                    1
#   报修日期                    NaT
#   解决问题日期                  NaT
#   报修问题                    NaN
#   解决方式                    NaN
#   解决人                     NaN
#   Name: 449, dtype: object,
#   'troubleUvDay1': ap_count              20
#   dhcp                 399
#   portal               360
#   prelogin             206
#   login                203
#   webforward           177
#   hardforward          183
#   forward_rate    0.458647
#   Name: 449, dtype: object,
#   'troubleUvDay2': ap_count              20
#   dhcp                 810
#   portal               691
#   prelogin             389
#   login                382
#   webforward           348
#   hardforward          364
#   forward_rate    0.449383
#   Name: 449, dtype: object}, '温县妇幼保健院': {'troubleRate': ap_count                 0
#   dhcp            -0.0211203
#   portal           -0.968876
#   prelogin        -0.0650602
#   login           -0.0510204
#   webforward       -0.026087
#   hardforward     -0.0149701
#   forward_rate    0.00628293
#   Name: 568, dtype: object,
#   'troubleTotal': hos_id                 568
#   故障类型            portal打点故障
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f4ca5c
#   网关品牌               ABLOOMY
#   医院名称               温县妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 568, dtype: object,
#   'troubleUvDay1': ap_count             17
#   dhcp               1066
#   portal               31
#   prelogin            388
#   login               372
#   webforward          336
#   hardforward         329
#   forward_rate    0.30863
#   Name: 568, dtype: object,
#   'troubleUvDay2': ap_count              17
#   dhcp                1089
#   portal               996
#   prelogin             415
#   login                392
#   webforward           345
#   hardforward          334
#   forward_rate    0.306703
#   Name: 568, dtype: object}, '温岭市妇幼保健院': {'troubleRate': ap_count        0.0208333
#   dhcp             -0.50591
#   portal          -0.544151
#   prelogin        -0.575937
#   login               -0.58
#   webforward      -0.571611
#   hardforward     -0.587968
#   forward_rate    -0.166079
#   Name: 817, dtype: object,
#   'troubleTotal': hos_id                     817
#   故障类型             未知  dhcp<-0.4
#   AP型号                    N200-单
#   AP品牌                        寰创
#   GWID(网关ID)    a63ebcfc940D475F
#   网关品牌                        寰创
#   医院名称                  温岭市妇幼保健院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 817, dtype: object,
#   'troubleUvDay1': ap_count              98
#   dhcp                 836
#   portal               604
#   prelogin             430
#   login                399
#   webforward           335
#   hardforward          363
#   forward_rate    0.434211
#   Name: 817, dtype: object,
#   'troubleUvDay2': ap_count              96
#   dhcp                1692
#   portal              1325
#   prelogin            1014
#   login                950
#   webforward           782
#   hardforward          881
#   forward_rate    0.520686
#   Name: 817, dtype: object}, '温州市瓯海区第三人民医院': {'troubleRate': ap_count            -0.2
#   dhcp           -0.146021
#   portal               NaN
#   prelogin             NaN
#   login                NaN
#   webforward           NaN
#   hardforward          NaN
#   forward_rate         NaN
#   Name: 853, dtype: object,
#   'troubleTotal': hos_id                     853
#   故障类型                      AP离线
#   AP型号                    N200-双
#   AP品牌                        寰创
#   GWID(网关ID)    61060300FF0C2770
#   网关品牌                        寰创
#   医院名称              温州市瓯海区第三人民医院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 853, dtype: object,
#   'troubleUvDay1': ap_count          24
#   dhcp            1041
#   portal             0
#   prelogin           0
#   login              0
#   webforward         0
#   hardforward        0
#   forward_rate       0
#   Name: 853, dtype: object,
#   'troubleUvDay2': ap_count          30
#   dhcp            1219
#   portal             0
#   prelogin           0
#   login              0
#   webforward         0
#   hardforward        0
#   forward_rate       0
#   Name: 853, dtype: object}, '眉山市妇幼保健院': {'troubleRate': ap_count        -0.166667
#   dhcp             0.194915
#   portal           0.163728
#   prelogin         0.204301
#   login            0.304878
#   webforward          0.375
#   hardforward      0.171429
#   forward_rate   -0.0196555
#   Name: 188, dtype: object,
#   'troubleTotal': hos_id                 188
#   故障类型                  AP离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f1b8a4
#   网关品牌               ABLOOMY
#   医院名称              眉山市妇幼保健院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 188, dtype: object,
#   'troubleUvDay1': ap_count              5
#   dhcp                564
#   portal              462
#   prelogin            112
#   login               107
#   webforward           77
#   hardforward          82
#   forward_rate    0.14539
#   Name: 188, dtype: object,
#   'troubleUvDay2': ap_count               6
#   dhcp                 472
#   portal               397
#   prelogin              93
#   login                 82
#   webforward            56
#   hardforward           70
#   forward_rate    0.148305
#   Name: 188, dtype: object}, '自贡市妇幼保健院': {'troubleRate': ap_count               0
#   dhcp           -0.187082
#   portal         -0.378251
#   prelogin       -0.467836
#   login          -0.478261
#   webforward     -0.517241
#   hardforward    -0.584507
#   forward_rate   -0.488887
#   Name: 195, dtype: object,
#   'troubleTotal': hos_id                 195
#   故障类型            带宽负载较高（疑似）
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    00f3d2001281
#   网关品牌           ABLOOMY-爱快刷
#   医院名称              自贡市妇幼保健院
#   医院级别                 B级,五线
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 195, dtype: object,
#   'troubleUvDay1': ap_count              14
#   dhcp                 365
#   portal               263
#   prelogin              91
#   login                 84
#   webforward            70
#   hardforward           59
#   forward_rate    0.161644
#   Name: 195, dtype: object,
#   'troubleUvDay2': ap_count              14
#   dhcp                 449
#   portal               423
#   prelogin             171
#   login                161
#   webforward           145
#   hardforward          142
#   forward_rate    0.316258
#   Name: 195, dtype: object}, '萧山区第二人民医院': {'troubleRate': ap_count       -1
#   dhcp           -1
#   portal         -1
#   prelogin       -1
#   login          -1
#   webforward     -1
#   hardforward    -1
#   forward_rate   -1
#   Name: 1304, dtype: object, 'troubleTotal': hos_id                1304
#   故障类型                  网关离线
#   AP型号               IAP-103
#   AP品牌                 Aruba
#   GWID(网关ID)    001631f8d7f2
#   网关品牌               ABLOOMY
#   医院名称             萧山区第二人民医院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 1304, dtype: object, 'troubleUvDay1': ap_count        0
#   dhcp            0
#   portal          0
#   prelogin        0
#   login           0
#   webforward      0
#   hardforward     0
#   forward_rate    0
#   Name: 1304, dtype: object, 'troubleUvDay2': ap_count             12
#   dhcp                492
#   portal              469
#   prelogin            283
#   login               277
#   webforward          240
#   hardforward         254
#   forward_rate    0.51626
#   Name: 1304, dtype: object}, '都昌县中医院': {'troubleRate': ap_count        0.454545
#   dhcp              1.1122
#   portal           0.79703
#   prelogin        0.346154
#   login           0.289474
#   webforward      0.078125
#   hardforward         0.25
#   forward_rate   -0.408199
#   Name: 954, dtype: object,
#   'troubleTotal': hos_id                 954
#   故障类型                  None
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f1bb14
#   网关品牌               ABLOOMY
#   医院名称                都昌县中医院
#   医院级别                  DEAD
#   status                   0
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 954, dtype: object,
#   'troubleUvDay1': ap_count              16
#   dhcp                 433
#   portal               363
#   prelogin             105
#   login                 98
#   webforward            69
#   hardforward           80
#   forward_rate    0.184758
#   Name: 954, dtype: object,
#   'troubleUvDay2': ap_count              11
#   dhcp                 205
#   portal               202
#   prelogin              78
#   login                 76
#   webforward            64
#   hardforward           64
#   forward_rate    0.312195
#   Name: 954, dtype: object}, '靖江市人民医院': {'troubleRate': ap_count        -0.230088
#   dhcp           -0.0565959
#   portal          -0.132231
#   prelogin        -0.148004
#   login            -0.14527
#   webforward      -0.158537
#   hardforward     -0.179328
#   forward_rate    -0.130094
#   Name: 1072, dtype: object,
#   'troubleTotal': hos_id                    1072
#   故障类型                      AP离线
#   AP型号                      N200
#   AP品牌                        寰创
#   GWID(网关ID)    61060300DF0C69DA
#   网关品牌                        寰创
#   医院名称                   靖江市人民医院
#   医院级别                        B级
#   status                     NaN
#   报修日期                       NaT
#   解决问题日期                     NaT
#   报修问题                       NaN
#   解决方式                       NaN
#   解决人                        NaN
#   Name: 1072, dtype: object,
#   'troubleUvDay1': ap_count              87
#   dhcp                2267
#   portal              1260
#   prelogin             875
#   login                759
#   webforward           621
#   hardforward          659
#   forward_rate    0.290693
#   Name: 1072, dtype: object,
#   'troubleUvDay2': ap_count             113
#   dhcp                2403
#   portal              1452
#   prelogin            1027
#   login                888
#   webforward           738
#   hardforward          803
#   forward_rate    0.334166
#   Name: 1072, dtype: object}, '首都医科大学附属复兴医院': {'troubleRate': ap_count        -0.166667
#   dhcp             0.227444
#   portal           0.201285
#   prelogin         0.097166
#   login           0.0853659
#   webforward       0.103448
#   hardforward     0.0726496
#   forward_rate    -0.126111
#   Name: 630, dtype: object,
#   'troubleTotal': hos_id                 630
#   故障类型                  AP离线
#   AP型号                  R300
#   AP品牌                Ruckus
#   GWID(网关ID)    001631f1b7c8
#   网关品牌               ABLOOMY
#   医院名称          首都医科大学附属复兴医院
#   医院级别                    B级
#   status                   1
#   报修日期                   NaT
#   解决问题日期                 NaT
#   报修问题                   NaN
#   解决方式                   NaN
#   解决人                    NaN
#   Name: 630, dtype: object,
#   'troubleUvDay1': ap_count             10
#   dhcp                653
#   portal              561
#   prelogin            271
#   login               267
#   webforward          256
#   hardforward         251
#   forward_rate    0.38438
#   Name: 630, dtype: object,
#   'troubleUvDay2': ap_count             12
#   dhcp                532
#   portal              467
#   prelogin            247
#   login               246
#   webforward          232
#   hardforward         234
#   forward_rate    0.43985
#   Name: 630, dtype: object}}

# %%
from docx import Document
from docx.shared import Inches
document = Document()
#添加主标题
document.add_heading(r'每日分析——20171019', 0)
#添加主标题下的内容
p = document.add_paragraph('A plain paragraph having some ')
p.add_run('bold').bold = True
p.add_run(' and some ')
p.add_run('italic.').italic = True

# %%
document.add_heading('Heading, level 1', level=1)
# document.add_paragraph('Intense quote', style='IntenseQuote')

document.add_paragraph(
    'first item in unordered list', style='ListBullet'
)
# document.add_paragraph(
#     'first item in ordered list', style='ListNumber'
# )

# document.add_picture('image.bmp', width=Inches(1))

table = document.add_table(rows=5, cols=8)
hdr_cells = table.rows[0].cells
# hdr_cells.cells=['a','b','c','d','e','f','g','h']
# hdr_cells[0].text = 'Qty'
# hdr_cells[1].text = 'Id' 
# hdr_cells[2].text = 'Desc'
# for item in range(3):
#     row_cells = table.add_row().cells
#     row_cells[0].text = str(item.qty)
#     row_cells[1].text = str(item.id)
#     row_cells[2].text = item.desc

document.add_page_break()

document.save('demo.docx')
# Out:
# /root/anaconda3/lib/python3.6/site-packages/docx/styles/styles.py:54: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   warn(msg, UserWarning)
