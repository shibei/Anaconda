# %%
import uv_monitor

# %%
help(uv_monitor)
# Out:
# Help on module uv_monitor:
#
# NAME
#     uv_monitor
#
# CLASSES
#     builtins.object
#         SqlServer
#
#     class SqlServer(builtins.object)
#      |  docstring for sqlServer
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, server)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  getAllData(self)
#      |
#      |  getOneData(self, key)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     analysis(day, cycle, apLimit=-0.1, forwardLimit=-0.4, globalLimit=-0.4)
#
#     chineseNumber(x)
#
#     connect(server)
#
#     dataClean(uvData, apData)
#         # 清洗数据
#
# ...

# %%
uv_monitor.analysis(1,2*7)
# Out:
# {'troubleRate':       hos_id            故障类型  ap_count      dhcp    portal  prelogin  \
#  0          0            None       NaN  0.005166 -0.029998       NaN
#  62        62      带宽负载较高（疑似）  0.000000 -0.271845 -0.312500 -0.642857
#  66        66            AP离线 -0.142857  0.149425  0.172727  0.119403
#  80        80           重定向故障  0.000000  0.000000 -1.000000 -1.000000
#  81        81           重定向故障  0.000000 -0.111693 -0.526316 -0.539033
#  101      101            网关离线 -1.000000 -1.000000 -1.000000 -1.000000
#  116      116            网关离线 -1.000000 -1.000000 -1.000000 -1.000000
#  118      118            网关离线 -1.000000 -1.000000 -1.000000 -1.000000
#  129      129            网关离线 -1.000000 -1.000000 -1.000000 -1.000000
#  158      158            AP离线 -0.545455 -0.232353 -0.177778 -0.355224
#  165      165            网关离线 -1.000000 -1.000000 -1.000000 -1.000000
#  186      186            AP离线 -0.111111  0.145933  0.202142  0.047566
# ...
